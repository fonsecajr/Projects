# %% [markdown]
# <a href="https://colab.research.google.com/github/fonsecajr/Projects/blob/master/S%C3%A9ries_AnalisesxA%C3%A7%C3%B5es_Analises9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install investpy
# Out:
# Requirement already satisfied: investpy in /usr/local/lib/python3.6/dist-packages (0.9.14)
# Requirement already satisfied: setuptools>=41.2.0 in /usr/local/lib/python3.6/dist-packages (from investpy) (46.3.0)
# Requirement already satisfied: Unidecode>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from investpy) (1.1.1)
# Requirement already satisfied: lxml>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from investpy) (4.5.1)
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.6/dist-packages (from investpy) (1.0.3)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.6/dist-packages (from investpy) (1.18.4)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.6/dist-packages (from investpy) (2.23.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.25.1->investpy) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.25.1->investpy) (2018.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->investpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->investpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->investpy) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->investpy) (2.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.25.1->investpy) (1.12.0)

# %%
import investpy as inv
import pandas as pd ; pd.set_option('display.max_rows', None)
import numpy as np
import seaborn as sns ; sns.set ()
import matplotlib.pyplot as plt
import matplotlib ; matplotlib.rcParams['figure.figsize'] = (22,8)

# %% [markdown]
# # Funds Analyses

# %%
funds_br = inv.get_funds_list(country='brazil')
funds_br

# %%
len(funds_br)

# %%
funds_br[:10]

# %%
search = inv.search_funds(by='name', value='alaska')
search

# %%
search['name'][6]

# %%
fund = 'Alaska Black Fundo De Investimento Em Cotas De Fundos De Investimento Em Ações Ii - Bdr Nível I'

# %%
alaska = inv.get_fund_historical_data(fund, country='brazil', from_date='01/01/1900', to_date='26/05/2020')['Close']

# %%
alaska

# %%
alaska.plot();

# %%
search2 = inv.search_funds(by='name', value='brasil capital')
search2

# %%
search2['name'][1]

# %%
fund2 = 'Brasil Capital Fundo De Investimento Em Cotas De Fundos De Investimento Em Ações'

# %%
Brasil = inv.get_fund_historical_data(fund2, country='brazil', from_date='01/01/1900', to_date='26/05/2020')['Close']

# %%
Brasil

# %%
Brasil.plot();

# %%
inv.get_etfs_overview(country='brazil')

# %%
BOVB11 = inv.get_etf_historical_data(etf='ETF Bradesco Ibovespa Fdo De Indice', country='brazil', from_date='01/01/1900', to_date='27/05/2020')['Close']
BOVB11

# %%
BOVB11.plot();

# %% [markdown]
# Alaska x Brasil x BOVB11

# %%
BOVB11.index[0]

# %%
compare = pd.DataFrame()
date_start = BOVB11.index[0]

compare['BOVB11'] = BOVB11 / BOVB11.loc[date_start]
compare['alaska'] = alaska / alaska.loc[date_start]
compare['Brasil'] = Brasil / Brasil.loc[date_start]

compare

# %%
compare.plot();

# %% [markdown]
# # Index Analyses

# %%
inv.get_indices_list('brazil')
# Out:
# ['MSCI Brazil Net USD',
#  'DJ Brazil',
#  'TR Brazil 50',
#  'MSCI Brazil Price USD',
#  'DJ Brazil Titans 20 ADR',
#  'BNY Mellon Brazil ADR',
#  'BNY Mellon Brazil ADR TR',
#  'BNY Mellon Brazil Classic ADR',
#  'BNY Mellon Brazil Classic ADR TR',
#  'FTSE RAFI Brazil 50',
#  'MSCI Brazil 10 40',
#  'DJ BRIC Brazil 15 Capped NTR',
#  'DJ BRIC Brazil 15 USD',
#  'DJ BRIC Brazil 15 EUR',
#  'FTSE Brazil Infrastructure Extended',
#  'MSCI Brazil Gross',
#  'DJ Brazil Titans 20 ADR TR',
#  'MSCI Brazil 25-50 Price',
#  'MSCI Brazil 20-50 Gross Return',
#  'MSCI Brazil 25-50 Net Return',
#  'FTSE Brazil Infrastructure Extended USD PR',
#  'FTSE Brazil Infrastructure Extended Total Return',
#  'FTSE Brazil Infrastructure Extended Net Tax Total',
#  'FTSE Brazil Infrastructure Extended Net Tax USD TR',
#  'DJ BRIC Brazil 15 DR',
#  'MSCI Brazil',
#  'BM&FBOVESPA Unsponsored BDRX',
#  'Small Cap Index',
#  'Tag Along',
#  'Brazil broad-Based',
#  'Brazil Index',
#  'Mid-Large Cap Index',
#  'Public Utilities',
#  'BM&FBOVESPA Real Estate IFIX',
#  'Financials',
#  'Carbon Efficient',
#  'Corporate Governance IGCNM',
#  'Bovespa Dividend',
#  'Brazil 50',
#  'Corporate Gov Trade',
#  'FTSE Brazil',
#  'Ibovespa EUR',
#  'Ibovespa USD',
#  'IVBX',
#  'IGCX',
#  'Consumption',
#  'Industrial Sector',
#  'Electrical Energy',
#  'Basic Materials',
#  'Bovespa',
#  'Corporate Sustainability',
#  'Real Estate']

# %%
inv.get_index_recent_data('Bovespa', country='Brazil') #Country é condicional
# Out:
#                 Open      High       Low     Close    Volume Currency
# Date
# 2020-04-28  78243.32  81427.32  78243.32  81312.23  12938969      BRL
# 2020-04-29  81312.89  83598.01  81312.89  83170.80  11719656      BRL
# 2020-04-30  83169.34  83169.34  80168.06  80505.89  11804571      BRL
# 2020-05-04  80501.17  80501.65  77640.22  78876.22   8594170      BRL
# 2020-05-05  78887.12  81065.90  78886.34  79470.78   9154697      BRL
# 2020-05-06  79472.78  79996.04  78055.82  79063.68   9775856      BRL
# 2020-05-07  79072.28  80061.19  78061.44  78118.57  13808910      BRL
# 2020-05-08  78151.87  80556.62  78151.87  80263.35  10734447      BRL
# 2020-05-11  80263.42  80722.75  78993.75  79064.60   9781947      BRL
# 2020-05-12  79064.60  80344.03  77871.95  77871.95  10245422      BRL
# 2020-05-13  77876.88  78911.28  77151.98  77772.20  11575865      BRL
# 2020-05-14  77770.48  79010.81  75696.95  79010.81  13818890      BRL
# 2020-05-15  79010.59  79538.23  77426.10  77556.62  11718213      BRL
# 2020-05-18  77575.71  81420.37  77571.39  81194.29  11533136      BRL
# 2020-05-19  81196.69  82174.55  80647.02  80742.35  10740120      BRL
# 2020-05-20  80746.81  82290.49  80739.61  81319.45   9522846      BRL
# 2020-05-21  81319.73  83308.96  81317.11  83027.09  11395210      BRL
# 2020-05-22  83027.09  83027.09  81668.80  82173.21   9281203      BRL
# 2020-05-25  82197.76  85875.60  82193.33  85663.48   8764426      BRL
# 2020-05-26  85667.50  87332.53  85395.71  85468.91  12030845      BRL
# 2020-05-27  85467.50  87946.25  85467.50  87946.25  11212003      BRL

# %%
Bovespa = inv.get_index_historical_data('Bovespa', country='Brazil', from_date='01/01/1900', to_date='27/05/2020')['Close']
Bovespa.head()
# Out:
# Date
# 2000-12-27    15186.15
# 2000-12-28    15259.29
# 2001-01-02    15425.34
# 2001-01-03    16599.42
# 2001-01-04    16675.06
# Name: Close, dtype: float64

# %%
Ibovespa_USD = inv.get_index_historical_data('Ibovespa USD', country='Brazil', from_date='01/01/1900', to_date='27/05/2020')['Close']
Ibovespa_USD.head()
# Out:
# Date
# 2018-02-19    26201.34
# 2018-02-20    26317.45
# 2018-02-21    26368.51
# 2018-02-22    26588.26
# 2018-02-23    26860.11
# Name: Close, dtype: float64

# %%
Ibovespa_EUR = inv.get_index_historical_data('Ibovespa EUR', country='Brazil', from_date='01/01/1900', to_date='27/05/2020')['Close']
Ibovespa_EUR.head()
# Out:
# Date
# 2011-10-10    22151.44
# 2011-10-11    22309.53
# 2011-10-13    22633.51
# 2011-10-14    22872.65
# 2011-10-17    22044.98
# Name: Close, dtype: float64

# %%
Bovespa_Dividend = inv.get_index_historical_data('Bovespa Dividend', country='Brazil', from_date='01/01/1900', to_date='27/05/2020')['Close']
Bovespa_Dividend.head()
# Out:
# Date
# 2011-08-12    2409.45
# 2011-08-15    2458.99
# 2011-08-16    2477.90
# 2011-08-17    2501.50
# 2011-08-18    2476.69
# Name: Close, dtype: float64

# %%
Ibovespa_USD.index[0]
# Out:
# Timestamp('2018-02-19 00:00:00')

# %%
indexes = pd.DataFrame()
date_start = Ibovespa_USD.index[0]

indexes['Ibovespa_USD'] = Ibovespa_USD / Ibovespa_USD.loc[date_start] #Must start on date reference dataset
indexes['Ibovespa_EUR'] = Ibovespa_EUR / Ibovespa_EUR.loc[date_start]
indexes['Bovespa_Dividend'] = Bovespa_Dividend / Bovespa_Dividend.loc[date_start]
indexes['Bovespa'] = Bovespa / Bovespa.loc[date_start]

indexes
# Out:
#             Ibovespa_USD  Ibovespa_EUR  Bovespa_Dividend   Bovespa
# Date
# 2018-02-19      1.000000      1.000000          1.000000  1.000000
# 2018-02-20      1.004431      1.010344          1.008545  1.011926
# 2018-02-21      1.006380      1.015907          1.014192  1.014849
# 2018-02-22      1.014767      1.021248          1.015583  1.022334
# 2018-02-23      1.025143      1.034277          1.022913  1.029490
# ...                  ...           ...               ...       ...
# 2020-05-20      0.545325      0.616011          1.056902  0.959038
# 2020-05-21      0.571013      0.646976          1.093906  0.979177
# 2020-05-22      0.556574      0.633834          1.084093  0.969107
# 2020-05-25      0.600656      0.683459          1.138522  1.010269
# 2020-05-26      0.609612      0.688515          1.132180  1.007975
#
# [557 rows x 4 columns]

# %%
indexes.plot();

# %% [markdown]
# # Stocks Analises

# %%
Stocks = inv.get_stocks(country='Brazil')
Stocks = Stocks.sort_values(by=['name'])
Stocks
# Out:
#     country  ...   symbol
# 296  brazil  ...   MMMC34
# 0    brazil  ...    ABCB4
# 75   brazil  ...    TIET3
# 76   brazil  ...    TIET4
# 355  brazil  ...   TIET11
# 547  brazil  ...   AIGB34
# 3    brazil  ...    ALPA3
# 4    brazil  ...    ALPA4
# 7    brazil  ...    ABEV3
# 9    brazil  ...    ARZZ3
# 276  brazil  ...   ATTB34
# 488  brazil  ...   ABBV34
# 272  brazil  ...   ABTT34
# 326  brazil  ...   ACNB34
# 8    brazil  ...    ADHM3
# 674  brazil  ...    TIET2
# 519  brazil  ...    AFLT3
# 638  brazil  ...    BRGE6
# 636  brazil  ...   BRGE11
# 637  brazil  ...   BRGE12
# 542  brazil  ...    RPAD3
# 439  brazil  ...    RPAD5
# 440  brazil  ...    RPAD6
# 633  brazil  ...    PEAB3
# 431  brazil  ...    PEAB4
# 5    brazil  ...    ALSO3
# 581  brazil  ...   ALZR11
# 501  brazil  ...   GOGL34
# 502  brazil  ...   GOGL35
# 609  brazil  ...    ALUP3
# 610  brazil  ...    ALUP4
# 200  brazil  ...   ALUP11
# 274  brazil  ...   AMZO34
# 553  brazil  ...   AALL34
# 277  brazil  ...   AXPB34
# 273  brazil  ...   AMGN34
# 385  brazil  ...    CBEE3
# 201  brazil  ...    ANIM3
# 271  brazil  ...   AAPL34
# 275  brazil  ...   ARMT34
# 487  brazil  ...   ARNC34
# 564  brazil  ...    CRFB3
# 353  brazil  ...    ATOM3
# 335  brazil  ...   AVON34
# 366  brazil  ...    AZEV4
# 623  brazil  ...    AZEV3
# 560  brazil  ...    AZUL4
# 28   brazil  ...    BTOW3
# 29   brazil  ...    B3SA3
# 16   brazil  ...    BPAN4
# 359  brazil  ...    BRSR3
# 185  brazil  ...    BRSR5
# 25   brazil  ...    BRSR6
# 684  brazil  ...   BBIM11
# 462  brazil  ...   BCFF11
# 720  brazil  ...   RDPD11
# 202  brazil  ...    BBSE3
# 419  brazil  ...    IDVL3
# 577  brazil  ...    BKBR3
# 463  brazil  ...  BMLC11B
# 379  brazil  ...    BNBR3
# 13   brazil  ...    BBRK3
# 687  brazil  ...  BRHT11B
# 20   brazil  ...    APER3
# 23   brazil  ...    BRML3
# 15   brazil  ...    BPHA3
# 24   brazil  ...    BRPR3
# 655  brazil  ...    BBDC3
# 11   brazil  ...    BBDC3
# 12   brazil  ...    BBDC4
# 17   brazil  ...    BRAP3
# 18   brazil  ...    BRAP4
# 10   brazil  ...    BBAS3
# 1    brazil  ...    AGRO3
# 21   brazil  ...    BRKM3
# 22   brazil  ...    BRKM5
# 383  brazil  ...    BSLI4
# 19   brazil  ...    BRFS3
# 729  brazil  ...    TCR11
# 552  brazil  ...   PPLA11
# 367  brazil  ...    BAHI3
# 381  brazil  ...    BRIV3
# 382  brazil  ...    BRIV4
# 741  brazil  ...    BMGB4
# 740  brazil  ...   BMGB11
# 551  brazil  ...   BPAC11
# 626  brazil  ...    BPAC3
# 635  brazil  ...    BPAC5
# 662  brazil  ...    IDVL9
# 670  brazil  ...    BIDI3
# 595  brazil  ...    BIDI4
# 602  brazil  ...   BIDI4T
# 669  brazil  ...   BIDI11
# 214  brazil  ...    BAZA3
# 520  brazil  ...    BGIP3
# 364  brazil  ...   ABCB10
# 373  brazil  ...    BGIP4
# 371  brazil  ...    BEES3
# 372  brazil  ...    BEES4
# 490  brazil  ...   BCRI11
# 279  brazil  ...   BOAC34
# 327  brazil  ...   BONY34
# 370  brazil  ...    BDLL4
# 683  brazil  ...   BARI11
# 384  brazil  ...    BTTL3
# 625  brazil  ...    BALM3
# 368  brazil  ...    BALM4
# 278  brazil  ...   BERK34
# 489  brazil  ...   BBYY34
# 378  brazil  ...    BMKS3
# 491  brazil  ...   BIIB34
# 211  brazil  ...    BIOM3
# 203  brazil  ...    BSEV3
# 565  brazil  ...   GBIO33
# 492  brazil  ...   BLAK34
# 310  brazil  ...   BOEI34
# 380  brazil  ...    BOBR4
# 588  brazil  ...   BOXP34
# 587  brazil  ...   BCIA11
# 688  brazil  ...   BVAR11
# 685  brazil  ...   BMII11
# 618  brazil  ...   CARE11
# 410  brazil  ...    ESTR4
# 336  brazil  ...   BMYB34
# 739  brazil  ...    CEAB3
# 30   brazil  ...    CAMB4
# 33   brazil  ...    CCRO3
# 190  brazil  ...    CCXC3
# 523  brazil  ...    CEBR3
# 34   brazil  ...    CEDO4
# 35   brazil  ...    CEED3
# 57   brazil  ...    EEEL3
# 193  brazil  ...    CLSC4
# 388  brazil  ...    CELP3
# 389  brazil  ...    CELP5
# 472  brazil  ...   ENMA3B
# 40   brazil  ...    CMIG3
# 41   brazil  ...    CMIG4
# 191  brazil  ...    CESP3
# 186  brazil  ...    CESP5
# 36   brazil  ...    CESP6
# 86   brazil  ...    HGTX3
# 39   brazil  ...    CIEL3
# 194  brazil  ...    COCE3
# 42   brazil  ...    COCE5
# 37   brazil  ...    CGAS5
# 48   brazil  ...    CSMG3
# 44   brazil  ...    CPLE3
# 45   brazil  ...    CPLE6
# 47   brazil  ...    CSAN3
# 398  brazil  ...    CTNM3
# 51   brazil  ...    CTNM4
# 43   brazil  ...    CPFE3
# 204  brazil  ...    CPRE3
# 392  brazil  ...   CPRE3T
# 46   brazil  ...    CRDE3
# 215  brazil  ...   HGBS11
# 534  brazil  ...   GRLV11
# 700  brazil  ...   HGFF11
# 216  brazil  ...   HGPO11
# 608  brazil  ...   HGRU11
# 599  brazil  ...   FOFT11
# 31   brazil  ...    CARD3
# 452  brazil  ...    TRPL3
# 205  brazil  ...    CVCB3
# 401  brazil  ...   CVCB3T
# 496  brazil  ...   CVSH34
# 32   brazil  ...    CCPR3
# 52   brazil  ...    CYRE3
# 661  brazil  ...   CAMB10
# 571  brazil  ...    CAML3
# 475  brazil  ...   FCFL11
# 280  brazil  ...   CATP34
# 524  brazil  ...    CEDO3
# 579  brazil  ...   CLGN34
# 533  brazil  ...    GPAR3
# 390  brazil  ...    CEPE5
# 434  brazil  ...    RANI3
# 435  brazil  ...    RANI4
# 535  brazil  ...    MAPT3
# 518  brazil  ...    AALR3
# 510  brazil  ...   SCHW34
# 493  brazil  ...   CHKE34
# 311  brazil  ...   CHVX34
# 283  brazil  ...   CSCO34
# 313  brazil  ...   CTGP34
# 386  brazil  ...    CEEB3
# 387  brazil  ...    CEEB5
# 196  brazil  ...    COGN3
# 495  brazil  ...   CTSH34
# 337  brazil  ...   COLG34
# 281  brazil  ...   CMCS34
# 391  brazil  ...    CGAS3
# 590  brazil  ...    MSPA3
# 356  brazil  ...    SAPR4
# 312  brazil  ...   COPH34
# 50   brazil  ...    LIQO3
# 641  brazil  ...    CORR4
# 269  brazil  ...    RLOG3
# 396  brazil  ...    CSRN3
# 494  brazil  ...   COWC34
# 338  brazil  ...   COTY34
# 394  brazil  ...    CRPG5
# 395  brazil  ...    CRPG6
# 53   brazil  ...    DASA3
# 54   brazil  ...    DIRR3
# 690  brazil  ...  DOVL11B
# 55   brazil  ...    DTEX3
# 328  brazil  ...   DHER34
# 498  brazil  ...   DEAI34
# 689  brazil  ...  DAMT11B
# 432  brazil  ...    PNVL3
# 433  brazil  ...    PNVL4
# 402  brazil  ...    DOHL4
# 622  brazil  ...   DMMO11
# 403  brazil  ...    DTCY3
# 583  brazil  ...   DDNB34
# 548  brazil  ...   DUKB34
# 267  brazil  ...    GEPA4
# 56   brazil  ...    ECOR3
# 58   brazil  ...    ELEK4
# 59   brazil  ...    ELET3
# 60   brazil  ...    ELET6
# 187  brazil  ...    ELPL3
# 407  brazil  ...    EMAE4
# 61   brazil  ...    EMBR3
# 62   brazil  ...    ENBR3
# 63   brazil  ...    ENGI4
# 119  brazil  ...    ENEV3
# 161  brazil  ...    EGIE3
# 64   brazil  ...    EQTL3
# 66   brazil  ...    ETER3
# 67   brazil  ...    EUCA4
# 68   brazil  ...    EVEN3
# 69   brazil  ...    EZTC3
# 470  brazil  ...  EDFO11B
# 691  brazil  ...  ELDO11B
# 627  brazil  ...    EALT3
# 404  brazil  ...    EALT4
# 406  brazil  ...    ELEK3
# 405  brazil  ...    EKTR4
# 640  brazil  ...    CELP7
# 639  brazil  ...    CELP6
# 631  brazil  ...    LIPR3
# 316  brazil  ...   LILY34
# 142  brazil  ...    ENAT3
# 628  brazil  ...    ECPR3
# 361  brazil  ...   ENGI11
# 409  brazil  ...    ENMT3
# 643  brazil  ...    ENMT4
# 408  brazil  ...    ENGI3
# 642  brazil  ...    EEEL4
# 692  brazil  ...   ERPA11
# 703  brazil  ...   KINP11
# 369  brazil  ...    BAUH4
# 285  brazil  ...   EXXO34
# 71   brazil  ...    FHER3
# 70   brazil  ...    FESA4
# 667  brazil  ...   VTLT11
# 621  brazil  ...   VSHO11
# 531  brazil  ...   FSPE11
# 233  brazil  ...   FPAB11
# 219  brazil  ...   ABCP11
# 224  brazil  ...   BPFF11
# 459  brazil  ...  ANCR11B
# 473  brazil  ...   FAED11
# 460  brazil  ...  ATSA11B
# 222  brazil  ...   BBRC11
# 221  brazil  ...   BBPO11
# 252  brazil  ...   RNDP11
# 225  brazil  ...   BRCR11
# 482  brazil  ...   JRDM11
# 686  brazil  ...   BPRP11
# 659  brazil  ...   BTCR11
# 521  brazil  ...   BNFS11
# 223  brazil  ...   BBVJ11
# 226  brazil  ...   CTXT11
# 468  brazil  ...  CXCE11B
# 235  brazil  ...   HGCR11
# 236  brazil  ...   HGLG11
# 227  brazil  ...   CXTL11
# 600  brazil  ...   THRA11
# 497  brazil  ...   CXRI11
# 467  brazil  ...  CPTS11B
# 522  brazil  ...   CBOP11
# 465  brazil  ...   CNES11
# 464  brazil  ...   CEOC11
# 244  brazil  ...   PQDP11
# 360  brazil  ...   DOMC11
# 228  brazil  ...   EURO11
# 474  brazil  ...  FAMB11B
# 471  brazil  ...   EDGA11
# 476  brazil  ...   FEXC11
# 261  brazil  ...   VRTA11
# 231  brazil  ...   FIXX11
# 230  brazil  ...   FIGS11
# 234  brazil  ...   HMOC11
# 668  brazil  ...   GTWR11
# 678  brazil  ...   HABT11
# 237  brazil  ...   HGRE11
# 256  brazil  ...   SHPH11
# 480  brazil  ...   HCRI11
# 481  brazil  ...   HTMX11
# 527  brazil  ...   FIIB11
# 246  brazil  ...   RBBV11
# 238  brazil  ...   JSRE11
# 240  brazil  ...   KNRE11
# 241  brazil  ...   KNRI11
# 239  brazil  ...   KNCR11
# 242  brazil  ...   MXRF11
# 529  brazil  ...   FMOF11
# 606  brazil  ...   MGFF11
# 484  brazil  ...   NSLU11
# 260  brazil  ...   VLOL11
# 245  brazil  ...   PRSV11
# 537  brazil  ...   PABY11
# 541  brazil  ...   RBDS11
# 248  brazil  ...   RBGS11
# 249  brazil  ...   RBRD11
# 592  brazil  ...   RBRF11
# 604  brazil  ...   RBRR11
# 251  brazil  ...   RDES11
# 250  brazil  ...   RBVO11
# 247  brazil  ...   RBCB11
# 253  brazil  ...   RNGO11
# 229  brazil  ...   RCRB11
# 665  brazil  ...   RBVA11
# 232  brazil  ...   FLMA11
# 254  brazil  ...   SAAG11
# 255  brazil  ...   SDIL11
# 257  brazil  ...   SPTW11
# 258  brazil  ...   TBOF11
# 607  brazil  ...   TGAR11
# 243  brazil  ...   ONEF11
# 259  brazil  ...   TRXL11
# 263  brazil  ...   XTED11
# 458  brazil  ...   ALMI11
# 485  brazil  ...   TRNT11
# 679  brazil  ...   RECT11
# 614  brazil  ...   FVPQ11
# 528  brazil  ...   FIVN11
# 620  brazil  ...   XPIN11
# 262  brazil  ...   XPCM11
# 530  brazil  ...   FNOR11
# 525  brazil  ...   ESUD11
# 526  brazil  ...   ESUT11
# 545  brazil  ...   XPOM11
# 73   brazil  ...    FLRY3
# 309  brazil  ...    WIZS3
# 314  brazil  ...   FBOK34
# 220  brazil  ...   RBED11
# 413  brazil  ...   FSRF11
# 341  brazil  ...   FDXB34
# 411  brazil  ...    FESA3
# 544  brazil  ...    VSPT3
# 357  brazil  ...    CRIV4
# 393  brazil  ...    CRIV3
# 499  brazil  ...   FSLR34
# 478  brazil  ...   FLRP11
# 578  brazil  ...   FMXB34
# 286  brazil  ...   FDMO34
# 266  brazil  ...    FRAS3
# 340  brazil  ...   FCXO34
# 532  brazil  ...   FSTU11
# 486  brazil  ...  WPLZ11B
# 605  brazil  ...   WPLZ11
# 318  brazil  ...   MFII11
# 412  brazil  ...   FNAM11
# 365  brazil  ...   ANIM3T
# 77   brazil  ...    GFSA3
# 84   brazil  ...    GSHP3
# 80   brazil  ...    GOAU3
# 81   brazil  ...    GOAU4
# 78   brazil  ...    GGBR3
# 79   brazil  ...    GGBR4
# 568  brazil  ...   GGRC11
# 82   brazil  ...    GOLL4
# 597  brazil  ...   GPIV33
# 414  brazil  ...    GPCP3
# 192  brazil  ...    CGRA3
# 38   brazil  ...    CGRA4
# 83   brazil  ...    GRND3
# 582  brazil  ...    GFSA1
# 503  brazil  ...   GPSI34
# 342  brazil  ...   GDBR34
# 287  brazil  ...   GEOO34
# 554  brazil  ...   GMCO34
# 698  brazil  ...  GESE11B
# 699  brazil  ...   HBTT11
# 500  brazil  ...   GILD34
# 589  brazil  ...   GPRO34
# 288  brazil  ...   GSGI34
# 329  brazil  ...    IGBR3
# 718  brazil  ...   RCFA11
# 658  brazil  ...    CNTO3
# 660  brazil  ...    VAMO3
# 325  brazil  ...    GUAR3
# 682  brazil  ...   ATCR11
# 85   brazil  ...    HBOR3
# 675  brazil  ...   HSML11
# 88   brazil  ...    HYPE3
# 416  brazil  ...    HBTS5
# 629  brazil  ...    HAGA3
# 415  brazil  ...    HAGA4
# 289  brazil  ...   HALI34
# 593  brazil  ...    HAPV3
# 673  brazil  ...   HCTR11
# 746  brazil  ...   HRDF11
# 672  brazil  ...   TFOF11
# 591  brazil  ...   HFOF11
# 417  brazil  ...    HETA4
# 291  brazil  ...   HPQB34
# 290  brazil  ...   HOME34
# 580  brazil  ...   HONB34
# 701  brazil  ...   HUSC11
# 418  brazil  ...    HOOT4
# 89   brazil  ...    IDNT3
# 91   brazil  ...    IGTA3
# 150  brazil  ...    ROMI3
# 90   brazil  ...    IDVL4
# 93   brazil  ...    INEP3
# 94   brazil  ...    INEP4
# 124  brazil  ...    MYPK3
# 567  brazil  ...    IRBR3
# 598  brazil  ...   IRDM11
# 95   brazil  ...    ITSA3
# 96   brazil  ...    ITSA4
# 97   brazil  ...    ITUB3
# 98   brazil  ...    ITUB4
# 650  brazil  ...    JBDU1
# 651  brazil  ...    JBDU2
# 420  brazil  ...    JBDU3
# 421  brazil  ...    JBDU4
# 693  brazil  ...   FINF11
# 550  brazil  ...    PARD3
# 744  brazil  ...   IBFF11
# 292  brazil  ...   ITLC34
# 315  brazil  ...   IBMB34
# 92   brazil  ...    MEAL3
# 653  brazil  ...   MYPK12
# 630  brazil  ...    ITEC3
# 504  brazil  ...   JCPC34
# 99   brazil  ...    JBSS3
# 101  brazil  ...    JHSF3
# 100  brazil  ...    JFEN3
# 294  brazil  ...   JPMC34
# 702  brazil  ...   JPPC11
# 102  brazil  ...    JSLG3
# 596  brazil  ...    JPSA3
# 293  brazil  ...   JNJB34
# 422  brazil  ...    JOPA3
# 423  brazil  ...    JOPA4
# 103  brazil  ...    KEPL3
# 612  brazil  ...   KNHY11
# 424  brazil  ...    KLBN3
# 104  brazil  ...    KLBN4
# 212  brazil  ...   KLBN11
# 397  brazil  ...    CTKA4
# 330  brazil  ...   KMBB34
# 561  brazil  ...   KNIP11
# 354  brazil  ...   KHCB34
# 555  brazil  ...   LBRN34
# 109  brazil  ...    LLIS3
# 108  brazil  ...    LIGT3
# 206  brazil  ...    LINX3
# 147  brazil  ...    RENT3
# 197  brazil  ...    LCAM3
# 110  brazil  ...    LOGN3
# 105  brazil  ...    LAME3
# 106  brazil  ...    LAME4
# 6    brazil  ...    AMAR3
# 112  brazil  ...    LREN3
# 111  brazil  ...    LPSB3
# 113  brazil  ...    LUPA3
# 704  brazil  ...  LATR11B
# 295  brazil  ...   LMTB34
# 611  brazil  ...    LOGG3
# 652  brazil  ...   LOGN12
# 114  brazil  ...    MDIA3
# 671  brazil  ...   DMAC11
# 116  brazil  ...    MGLU3
# 115  brazil  ...    MGEL4
# 136  brazil  ...    POMO3
# 137  brazil  ...    POMO4
# 120  brazil  ...    MRFG3
# 122  brazil  ...    MTIG4
# 107  brazil  ...    LEVE3
# 74   brazil  ...    FRIO3
# 428  brazil  ...    MTSA4
# 117  brazil  ...    MILS3
# 14   brazil  ...    BEEF3
# 118  brazil  ...    MMXM3
# 536  brazil  ...   MMXM11
# 666  brazil  ...   MRSA3B
# 466  brazil  ...  MRSA6BF
# 121  brazil  ...    MRVE3
# 123  brazil  ...    MULT3
# 505  brazil  ...   MACY34
# 546  brazil  ...   POMO10
# 298  brazil  ...   MSCD34
# 483  brazil  ...   MAXR11
# 317  brazil  ...   MCDC34
# 506  brazil  ...   MDTC34
# 645  brazil  ...    MEND6
# 425  brazil  ...    MEND5
# 663  brazil  ...   MELI34
# 646  brazil  ...    MERC4
# 376  brazil  ...    BMIN3
# 377  brazil  ...    BMIN4
# 374  brazil  ...    BMEB3
# 217  brazil  ...   MBRF11
# 375  brazil  ...    BMEB4
# 297  brazil  ...   MRCK34
# 647  brazil  ...    RSUL4
# 331  brazil  ...   METB34
# 299  brazil  ...   MSFT34
# 649  brazil  ...   BEEF11
# 427  brazil  ...    MNPR3
# 344  brazil  ...   MDLZ34
# 664  brazil  ...    MOAR3
# 319  brazil  ...   MSBR34
# 549  brazil  ...    MOVI3
# 713  brazil  ...   PRTS11
# 726  brazil  ...   SHOP11
# 469  brazil  ...  DRIT11B
# 426  brazil  ...    MNDL3
# 125  brazil  ...    NATU3
# 705  brazil  ...   NCHB11
# 576  brazil  ...    NEOE3
# 706  brazil  ...   NPAR11
# 320  brazil  ...   NFLX34
# 300  brazil  ...   NIKE34
# 594  brazil  ...    GNDI3
# 708  brazil  ...  NVIF11B
# 707  brazil  ...   NVHO11
# 213  brazil  ...    NUTR3
# 126  brazil  ...    ODPV3
# 26   brazil  ...    OIBR3
# 27   brazil  ...    OIBR4
# 127  brazil  ...    OSXB3
# 613  brazil  ...   OUCY11
# 430  brazil  ...   DMMO3T
# 363  brazil  ...    DMMO3
# 566  brazil  ...    OMGE3
# 697  brazil  ...  FTCE11B
# 301  brazil  ...   ORCL34
# 586  brazil  ...   OUJP11
# 710  brazil  ...  OULG11B
# 736  brazil  ...  WTSP11B
# 268  brazil  ...    OFSA3
# 709  brazil  ...   ORPD11
# 128  brazil  ...    PCAR4
# 135  brazil  ...    PMAM3
# 654  brazil  ...   PATC11
# 129  brazil  ...    PDGR3
# 130  brazil  ...    PETR3
# 131  brazil  ...    PETR4
# 87   brazil  ...    PRIO3
# 141  brazil  ...    PTNT4
# 133  brazil  ...    PINE4
# 134  brazil  ...    PLAS3
# 139  brazil  ...    PSSA3
# 140  brazil  ...    PTBL3
# 138  brazil  ...    POSI3
# 132  brazil  ...    PFRM3
# 632  brazil  ...    PATI3
# 538  brazil  ...    PATI4
# 574  brazil  ...   SAPR11
# 696  brazil  ...   FPNG11
# 321  brazil  ...   PEPB34
# 712  brazil  ...  PRSN11B
# 575  brazil  ...    BRDT3
# 302  brazil  ...   PFIZ34
# 539  brazil  ...   PLRI11
# 540  brazil  ...   PORD11
# 735  brazil  ...   VPSI11
# 148  brazil  ...    FRTA3
# 303  brazil  ...   PGCO34
# 461  brazil  ...  BBFI11B
# 711  brazil  ...   PBLV11
# 143  brazil  ...    QUAL3
# 346  brazil  ...   QCOM34
# 198  brazil  ...    RADL3
# 144  brazil  ...    RAPT3
# 145  brazil  ...    RAPT4
# 477  brazil  ...  FIIP11B
# 714  brazil  ...   RBCO11
# 719  brazil  ...  RCRI11B
# 717  brazil  ...   RBRY11
# 716  brazil  ...   RBRP11
# 149  brazil  ...   RNEW11
# 146  brazil  ...    RDNI3
# 151  brazil  ...    RSID3
# 2    brazil  ...    RAIL3
# 743  brazil  ...   RBCO11
# 747  brazil  ...   RSPD11
# 436  brazil  ...    RCSL3
# 437  brazil  ...    RCSL4
# 438  brazil  ...    REDE3
# 358  brazil  ...    RPMG3
# 558  brazil  ...    RNEW3
# 559  brazil  ...    RNEW4
# 715  brazil  ...   RBFF11
# 569  brazil  ...    GEPA3
# 508  brazil  ...   ROST34
# 153  brazil  ...    SBSP3
# 570  brazil  ...    SAPR3
# 152  brazil  ...   SANB11
# 264  brazil  ...    SANB3
# 188  brazil  ...    SANB4
# 154  brazil  ...    SCAR3
# 159  brazil  ...    SMTO3
# 158  brazil  ...    SLED4
# 694  brazil  ...   FISC11
# 543  brazil  ...   SCPF11
# 742  brazil  ...   SDIP11
# 49   brazil  ...    CSNA3
# 157  brazil  ...    SLCE3
# 265  brazil  ...    SEDU3
# 727  brazil  ...   SPAF11
# 155  brazil  ...    SGPS3
# 728  brazil  ...   STRX11
# 160  brazil  ...   SULA11
# 512  brazil  ...   SSFO34
# 509  brazil  ...   SANC34
# 362  brazil  ...    SNSY5
# 722  brazil  ...   SADI11
# 399  brazil  ...    CTSA3
# 400  brazil  ...    CTSA4
# 189  brazil  ...    STBP3
# 624  brazil  ...    AHEB3
# 444  brazil  ...    SLED3
# 322  brazil  ...   SLBG34
# 352  brazil  ...    SHUL4
# 210  brazil  ...    SQIA3
# 207  brazil  ...    SEER3
# 441  brazil  ...   SEER3T
# 725  brazil  ...  SHDP11B
# 723  brazil  ...  SAIC11B
# 208  brazil  ...    SMLS3
# 445  brazil  ...   SMLS3T
# 721  brazil  ...   REIT11
# 446  brazil  ...    SOND5
# 447  brazil  ...    SOND6
# 448  brazil  ...    SPRI3
# 511  brazil  ...   SPRN34
# 304  brazil  ...   SBUB34
# 648  brazil  ...    SULA4
# 634  brazil  ...    SULA3
# 573  brazil  ...    SUZB3
# 695  brazil  ...   FISD11
# 724  brazil  ...   SFND11
# 619  brazil  ...    TAEE3
# 601  brazil  ...    TAEE4
# 170  brazil  ...   TAEE11
# 172  brazil  ...    TRPN3
# 163  brazil  ...    TECN3
# 162  brazil  ...    TCSA3
# 165  brazil  ...    TGMA3
# 164  brazil  ...    TEKA4
# 181  brazil  ...    VIVT3
# 182  brazil  ...    VIVT4
# 178  brazil  ...    TESA3
# 166  brazil  ...    TIMP3
# 156  brazil  ...    SHOW3
# 167  brazil  ...    TOTS3
# 171  brazil  ...    TRPL4
# 169  brazil  ...    TRIS3
# 168  brazil  ...    TPIS3
# 333  brazil  ...   TGTB34
# 195  brazil  ...    TASA3
# 72   brazil  ...    TASA4
# 615  brazil  ...   TASA13
# 616  brazil  ...   TASA15
# 617  brazil  ...   TASA17
# 451  brazil  ...    TOYB4
# 270  brazil  ...    TOYB3
# 218  brazil  ...    TCNO3
# 449  brazil  ...    TCNO4
# 450  brazil  ...    TELB3
# 332  brazil  ...    TELB4
# 562  brazil  ...    TEND3
# 563  brazil  ...   TSLA34
# 347  brazil  ...   TEXA34
# 585  brazil  ...    TXRX4
# 282  brazil  ...   COCA34
# 343  brazil  ...   HSHY34
# 345  brazil  ...   MOSC34
# 350  brazil  ...   WUNI34
# 513  brazil  ...   TMOS34
# 348  brazil  ...   TIFF34
# 730  brazil  ...   TORM13
# 731  brazil  ...   TOUR11
# 732  brazil  ...   TSNC11
# 507  brazil  ...   RIGG34
# 514  brazil  ...   TRVC34
# 748  brazil  ...   TCPF11
# 644  brazil  ...    LUXM4
# 209  brazil  ...    TUPY3
# 556  brazil  ...   TWTR34
# 324  brazil  ...   USBC34
# 584  brazil  ...   UBSG34
# 173  brazil  ...    UGPA3
# 199  brazil  ...    UCAS3
# 174  brazil  ...    UNIP3
# 175  brazil  ...    UNIP6
# 176  brazil  ...    USIM3
# 177  brazil  ...    USIM5
# 454  brazil  ...    USIM6
# 557  brazil  ...   UPAC34
# 453  brazil  ...    UNIP5
# 323  brazil  ...   UPSS34
# 515  brazil  ...   USSX34
# 349  brazil  ...   UTEC34
# 179  brazil  ...    VALE3
# 183  brazil  ...    VLID3
# 656  brazil  ...   VGIR11
# 479  brazil  ...   FVBI11
# 657  brazil  ...   VILG11
# 180  brazil  ...    VIVR3
# 516  brazil  ...   VLOE34
# 745  brazil  ...   CVBI11
# 734  brazil  ...   VLJS11
# 733  brazil  ...   VERE11
# 305  brazil  ...   VERZ34
# 456  brazil  ...    VVAR3
# 572  brazil  ...   VISC11
# 306  brazil  ...   VISA34
# 738  brazil  ...    VIVA3
# 455  brazil  ...    VULC3
# 184  brazil  ...    WEGE3
# 442  brazil  ...    WLMM3
# 443  brazil  ...    WLMM4
# 307  brazil  ...   WALM34
# 284  brazil  ...   DISB34
# 308  brazil  ...   WFCO34
# 429  brazil  ...    MWET4
# 457  brazil  ...    WHRL4
# 334  brazil  ...    WHRL3
# 517  brazil  ...   WSON33
# 676  brazil  ...   XPHT11
# 677  brazil  ...   XPHT12
# 603  brazil  ...   XPLG11
# 351  brazil  ...   XRXB34
# 65   brazil  ...    YDUQ3
# 737  brazil  ...   YCHY11
# 339  brazil  ...   EBAY34
# 680  brazil  ...   AQLL11
# 681  brazil  ...  ARFI11B
#
# [749 rows x 6 columns]

# %%
inv.get_stock_company_profile('ITUB3', country='Brazil')
# Out:
# {'desc': "Itau Unibanco Holding S.A. is a holding company. The Company provides a range of financial products and services to individual and corporate clients in Brazil and abroad. The Company operates through three segments: Retail Banking, Wholesale Banking, and Activities with the Market + Corporation. The Retail Banking segment offers banking products and services to a diversified client base of account holders and non-account holders, individuals and companies. The Wholesale Banking segment offers products and services to middle-market companies, high-net worth clients (Private Banking) and institutional clients. The Company's Activities with the Market + Corporation segment mainly manages the financial results associated with capital surplus, subordinated debt, and net debt of tax credits and debits. The Company provides banking activities, through its commercial, investment, real estate loan, finance and investment credit, and lease portfolios, including foreign exchange operations.",
#  'url': 'https://www.investing.com/equities/itauunibanco-on-edj-n1-company-profile'}

# %%
itau = inv.get_stock_historical_data('ITUB3', country='brazil', from_date='01/01/1900', to_date='27/05/2020')['Close']

# %%
itau.head()
# Out:
# Date
# 1992-10-20    0.0
# 1992-10-21    0.0
# 1992-10-22    0.0
# 1992-10-26    0.0
# 1992-10-27    0.0
# Name: Close, dtype: float64

# %%
inv.get_stock_information('ITUB3', country='Brazil')
# Out:
#   Stock Symbol  Prev. Close  ... Shares Outstanding  Next Earnings Date
# 0        ITUB3         21.9  ...       9.762259e+09          03/08/2020
#
# [1 rows x 16 columns]

# %%
bradesco.head()
# Out:
# Date
# 1992-10-20    0.0
# 1992-10-21    0.0
# 1992-10-22    0.0
# 1992-10-23    0.0
# 1992-10-26    0.0
# Name: Close, dtype: float64

# %%
inv.get_stock_information('BBDC3', country='Brazil')
# Out:
#   Stock Symbol  Prev. Close  ... Shares Outstanding  Next Earnings Date
# 0        BBDC3        17.83  ...       8.835527e+09          30/07/2020
#
# [1 rows x 16 columns]

# %%
brasil = inv.get_stock_historical_data('BBAS3', country='brazil', from_date='01/01/1900', to_date='27/05/2020')['Close']

# %%
brasil.head()
# Out:
# Date
# 1992-10-20    0.02
# 1992-10-21    0.02
# 1992-10-22    0.02
# 1992-10-23    0.02
# 1992-10-26    0.02
# Name: Close, dtype: float64

# %%
inv.get_stock_information('BBAS3', country='Brazil')
# Out:
#   Stock Symbol  Prev. Close  ... Shares Outstanding  Next Earnings Date
# 0        BBAS3         30.9  ...       2.850958e+09          06/08/2020
#
# [1 rows x 16 columns]

# %%
bancos = pd.DataFrame()

bancos['itau'] = itau
bancos['bradesco'] = bradesco
bancos['brasil'] = brasil

bancos.head()
# Out:
#             itau  bradesco  brasil
# Date
# 1992-10-20   0.0       0.0    0.02
# 1992-10-21   0.0       0.0    0.02
# 1992-10-22   0.0       0.0    0.02
# 1992-10-26   0.0       0.0    0.02
# 1992-10-27   0.0       0.0    0.02

# %%
bancos.plot();
