# %% [markdown]
# <a href="https://colab.research.google.com/github/fonsecajr/Projects/blob/master/Selenium_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install chromium, its driver, and selenium
# !apt install chromium-chromedriver
# !pip install selenium
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (83.0.4103.61-0ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 33 not upgraded.
# Requirement already satisfied: selenium in /usr/local/lib/python3.6/dist-packages (3.141.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from selenium) (1.24.3)

# %%
import pandas as pd

# %%
wd = webdriver.Chrome('chromedriver',options=options)

# %%
url = ('https://www.fundsexplorer.com.br/ranking')
wd.get(url)
print(wd.page_source)
# Out:
# <html lang="pt-br"><head>
#     <title>Ranking de Fundos Imobiliários - Funds Explorer</title>
#
#     <!-- Facebook Pixel Code -->
#     <script src="https://static.hotmart.com/hot-gdpr/cookieconsent.min.js?account=ea65c2cd-8a92-492b-94cd-88032dc5e373" async=""></script><script src="https://identification.hotmart.com/id.min.js?account=ea65c2cd-8a92-492b-94cd-88032dc5e373" async=""></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/gtm/js?id=GTM-PDXH77K&amp;t=gtm1&amp;cid=2060161608.1593574010"></script><script src="https://diffuser-cdn.app-us1.com/diffuser/diffuser.js" async=""></script><script async="" src="//launcher.hotmart.com/launcher.js"></script><script type="text/javascript" async="" src="//www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="https://static.hotjar.com/c/hotjar-1183503.js?sv=7"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-PRZL8BR"></script><script src="https://connect.facebook.net/signals/config/428828484703522?v=2.9.21&amp;r=stable" async=""></script><script src="https://connect.facebook.net/signals/config/116146375533905?v=2.9.21&amp;r=stable" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script>
#         ! function(f, b, e, v, n, t, s) {
#             if (f.fbq) return;
#             n = f.fbq = function() {
#                 n.callMethod ?
#                     n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#             };
#             if (!f._fbq) f._fbq = n;
#             n.push = n;
#             n.loaded = !0;
#             n.version = '2.0';
#             n.queue = [];
#             t = b.createElement(e);
#             t.async = !0;
#             t.src = v;
#             s = b.getElementsByTagName(e)[0];
#             s.parentNode.insertBefore(t, s)
#         }(window,
#             document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '116146375533905'); // Insert your pixel ID here.
#         fbq('track', 'PageView');
#     </script>
#     <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=116146375533905&ev=PageView&noscript=1" /></noscript>
#     <!-- DO NOT MODIFY -->
#     <!-- End Facebook Pixel Code -->
#
#     <!-- Google Tag Manager -->
#     <script>
#         (function(w, d, s, l, i) {
#             w[l] = w[l] || [];
#             w[l].push({
#                 'gtm.start': new Date().getTime(),
#                 event: 'gtm.js'
#             });
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s),
#                 dl = l != 'dataLayer' ? '&l=' + l : '';
#             j.async = true;
#             j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-PRZL8BR');
#     </script>
#     <!-- End Google Tag Manager -->
#
#     <meta property="og:locale" content="pt_BR">
#     <meta property="og:type" content="website">
#     <meta property="og:url" content="https://www.fundsexplorer.com.br/ranking">
#     <meta property="og:site_name" content="Funds Explorer">
#     <meta property="og:image" content="https://www.fundsexplorer.com.br/assets/og-image-0816da80381841e4393b12135f6f570531125da8618d8fda87c2da7c88700073.jpg">
#     <meta property="og:image:secure_url" content="https://www.fundsexplorer.com.br/assets/og-image-0816da80381841e4393b12135f6f570531125da8618d8fda87c2da7c88700073.jpg">
#     <meta property="og:image:width" content="1200">
#     <meta property="og:image:height" content="630">
#
#     <meta name="twitter:card" content="summary_large_image">
#     <meta name="twitter:site" content="@FundsExplorer">
#     <meta name="twitter:image" content="https://www.fundsexplorer.com.br/assets/og-image-0816da80381841e4393b12135f6f570531125da8618d8fda87c2da7c88700073.jpg">
#     <meta name="twitter:creator" content="@FundsExplorer">
#
#     <meta name="robots" content="index, follow">
#     <meta name="publisher" content="fundsexplorer.com.br">
#
#     <meta name="viewport" content="user-scalable=no, initial-scale=1, maximum-scale=1, minimum-scale=1, width=device-width, height=device-height, target-densitydpi=device-dpi">
#     <meta name="description" content="O ranking do Funds Explorer auxilia o investidor a pesquisar e tomar decisões mais assertivas. Conheça os melhores FIIs de acordo com cada indicador.">
# <meta property="og:description" content="O ranking do Funds Explorer auxilia o investidor a pesquisar e tomar decisões mais assertivas. Conheça os melhores FIIs de acordo com cada indicador.">
# <meta property="og:title" content="Ranking de Fundos Imobiliários - Funds Explorer">
# <meta name="twitter:title" content="Ranking de Fundos Imobiliários - Funds Explorer">
# <link rel="canonical" href="https://www.fundsexplorer.com.br/ranking">
#
#     <link rel="apple-touch-icon" sizes="180x180" href="/assets/favicon/apple-touch-icon-44ef885b225b78ca364401a65eb92e8e1a32447e44e4cc450c0d0af3d82c5c31.png">
# <link rel="icon" type="image/png" sizes="32x32" href="/assets/favicon/favicon-32x32-62f6aacd7a6c99219e86b4a6c140f7a8acfc6053f8d98a5655e536ca6d8fa675.png">
# <link rel="icon" type="image/png" sizes="16x16" href="/assets/favicon/favicon-16x16-20d8ccbcf748d21abeda416d0972cee05a5a0f85e718d55f16191e762ab97cd7.png">
# <link rel="manifest" href="/assets/favicon/site-865960af7b2e68f85fff7a4bc84e9d9209c01649f303579749b0f19c3d46b168.webmanifest">
# <link rel="mask-icon" href="/assets/favicon/safari-pinned-tab-43a00e43cf209aa71bb4e37ea4d86708c6cfa9e50877ed4ad6668dbed64a394a.svg" color="#09aac8">
# <link rel="shortcut icon" href="/assets/favicon/favicon-42a2d8bc26ccaf8666f9f0a22559e1c144f1bd2b7a73008674b6e5ee9eb21bd2.ico">
# <meta name="msapplication-TileColor" content="#2b5797">
# <meta name="msapplication-TileImage" content="/assets/favicon/mstile-144x144-b57ec78adf4959903834172ecf9e783789dc2a54552a84adf4e2529e1af3c19e.png">
# <meta name="msapplication-config" content="/assets/favicon/browserconfig-b277ccf9dd97fd937ead695a86ffb5e5b734d5aa624e225a6d4685424880f674.xml">
# <meta name="theme-color" content="#ffffff">
#     <link rel="stylesheet" media="all" href="/assets/redesign/application-c13a0e1ab4132ab396a8d457572d30923e353414bf4a483721adc83e25687b27.css" data-turbolinks-track="false">
#     <meta name="csrf-param" content="authenticity_token">
# <meta name="csrf-token" content="cZoG2ibj3c6zdU0psShXtB6B++7ao1XfjyfPo9xcGHMUmdpjE3T9Hf0dzgkbnWCHYRabt+q4KjrS1Ps5ou0AYg==">
# <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/689700318/?random=1593574117032&amp;cv=9&amp;fst=1593574117032&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=600&amp;u_w=800&amp;u_ah=600&amp;u_aw=800&amp;u_cd=24&amp;u_his=2&amp;u_tz=0&amp;u_java=false&amp;u_nplug=0&amp;u_nmime=0&amp;gtm=2wg6o0&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.fundsexplorer.com.br%2Franking&amp;tiba=Ranking%20de%20Fundos%20Imobili%C3%A1rios%20-%20Funds%20Explorer&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script type="text/javascript" charset="utf-8" src="https://prism.app-us1.com?a=649580125&amp;u=https%3A%2F%2Fwww.fundsexplorer.com.br%2Franking"></script><style type="text/css">/* Chart.js */
# @-webkit-keyframes chartjs-render-animation{from{opacity:0.99}to{opacity:1}}@keyframes chartjs-render-animation{from{opacity:0.99}to{opacity:1}}.chartjs-render-monitor{-webkit-animation:chartjs-render-animation 0.001s;animation:chartjs-render-animation 0.001s;}</style><script type="text/javascript" charset="utf-8" src="https://trackcmp.net/t_prism_sitemessages.php?trackid=649580125&amp;prismid=86a10edc-0d30-431b-a6e2-f7aebe2ed8c1&amp;url=https%3A%2F%2Fwww.fundsexplorer.com.br%2Franking"></script></head>
#
# <body>
#     <!-- Google Tag Manager (noscript) -->
#     <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PRZL8BR" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#     <!-- End Google Tag Manager (noscript) -->
#
#     <header>
#   <div id="menu">
#     <div class="container">
#       <div class="row">
#         <div class="col-md-3 col-xs-8">
#           <a id="header-logo" href="/"><img alt="Logo Funds Explorer" src="/assets/logo-974c9a6614072272315844e7bd6f6544cbd3cac96f2c5eb0ddc2d8d1a94b454c.png"></a>
#         </div>
#         <div class="col-md-6 hidden-xs">
#           <div id="menu-items">
#             <ul>
#               <li>
#                 <a class="menu-item hoverable-submenu" data-item="ferramentas" href="javascript:;"><span>Ferramentas</span><img alt="Ferramentas" src="/assets/icons/seta-1dc3b61873daa6f322a3e31bd11981f1c47eaba5863a3057c60c38f0816071e0.png"></a>
#                 <div id="menu-marker-ferramentas" class="menu-selected-marker"></div>
#               </li>
#               <li>
#                 <a class="menu-item" target="_blank" id="signature-button" href="https://lp.fundsexplorer.com.br/carteira-de-investimento-em-fiis/"><span>Assinatura</span></a>
#               </li>
#               <li>
#                 <a class="menu-item" target="_blank" id="mentoring-button" href="https://lp.fundsexplorer.com.br/funds-explorer-mentoria/"><span>Mentoria</span></a>
#               </li>
#               <li>
#                 <a class="menu-item" target="_blank" id="course-button" href="https://lp.fundsexplorer.com.br/curso-fundsexplorer-learning"><span>Curso Online</span></a>
#               </li>
#               <li>
#                 <a class="menu-item hoverable-submenu" id="free-button" data-item="gratuito" href="javascript:;"><span>Gratuito</span><img alt="Gratuito" src="/assets/icons/seta-1dc3b61873daa6f322a3e31bd11981f1c47eaba5863a3057c60c38f0816071e0.png"></a>
#                 <div id="menu-marker-gratuito" class="menu-selected-marker"></div>
#               </li>
#             </ul>
#           </div>
#         </div>
#         <div class="col-md-3 col-xs-4">
#           <div id="menu-user-actions">
#             <button id="btn-toggle-search">
#               <img alt="Buscar" id="search-mobile" src="/assets/icons/search-d5669d54dc062ed62f9e4e7173db8c9fa39cc760779dff386436f5faf48640bf.png">
#               <img alt="Buscar" id="search-desktop" src="/assets/icons/search-azul-6c8a9ad9f20cdb72bdb7a8fb980d8256f13f569aead6fd767533c48e8a2d8206.png">
#             </button>
#             <a id="subscribe-link" class="hidden" href="/area-assinante/dashboard"><img alt="Área do Assinante" src="/assets/icons/recomendacoes-61834a825604fdc064542346b6eeb512efa1003e5672378d2c6f33cec14c910a.png"><span>Área do Assinante</span></a>
#             <button id="btn-toggle-menu-mobile">
#               <img alt="Menu mobile" src="/assets/icons/new-menu-mobile-2c055d9a203314f1d20d2edceb4aa9b8018bb241e9c64d42a405e93bf1ff35f2.png">
#             </button>
#             <span id="loading-user-menu">Autenticando...</span>
#             <a id="btn-my-account" class="btn hidden" data-item="subscriber" href="/meus-dados"><img class="profile" src="/assets/icons/profile-e1626371c4a19db72fe7eb8943096747b6d7a8076d88e08f202a98baf342d782.png"><span></span><img alt="usuario" class="seta hidden" src="/assets/icons/seta-1dc3b61873daa6f322a3e31bd11981f1c47eaba5863a3057c60c38f0816071e0.png"></a>
#             <a id="btn-logout" class="btn hidden" href="/users/sign_out">Sair</a>
#             <a id="btn-signin" class="btn hidden" href="javascript:;">Entrar</a>
#             <a id="btn-sign-now" target="_blank" class="btn hidden" href="https://lp.fundsexplorer.com.br/carteira-de-investimento-em-fiis/">Assine agora</a>
#           </div>
#         </div>
#       </div>
#       <div id="signin-container">
#         <div id="signin-wrapper" class="menu-user-actions-wrapper">
#           <div id="menu-marker-signin" class="menu-selected-marker"></div>
#           <div class="close-signin-signup-wrapper">
#             <a id="close-signin" class="close-signin-signup" href="javascript:;"><img alt="Fechar login" src="/assets/icons/fechar-b42fc0c933cfffdbf591556fc1b9f2dc2ed1601e6b39ae0c48289bcf6802b1fe.png"></a>
#           </div>
#
#           <form id="form-signin" action="/users/sign_in" accept-charset="UTF-8" method="post"><input name="utf8" type="hidden" value="✓"><input type="hidden" name="authenticity_token" value="cZoG2ibj3c6zdU0psShXtB6B++7ao1XfjyfPo9xcGHMUmdpjE3T9Hf0dzgkbnWCHYRabt+q4KjrS1Ps5ou0AYg==">
#           <span id="signin-title">Identifique-se</span>
#             <div class="row">
#               <div class="form-group col-md-12 col-xs-12">
#                   <input id="email-signin" autocomplete="username email" class="fe-input signin-signup-input form-control" placeholder="Seu email" type="email" name="user[email]">
#               </div>
#             </div>
#             <div class="row">
#               <div class="form-group col-md-12 col-xs-12">
#                 <input id="password-signin" autocomplete="password" class="fe-input signin-signup-input form-control" placeholder="Digite a senha" type="password" name="user[password]">
#               </div>
#             </div>
#             <div class="row">
#               <div class="checkbox col-md-12 col-xs-12">
#                 <label for="remember-me">
#                   <input name="user[remember_me]" type="hidden" value="0"><input id="remember-me" type="checkbox" value="1" name="user[remember_me]">Lembrar
#                 </label>
#                 <a id="forgot-password" href="javascript:;">Esqueceu a senha?</a>
#               </div>
#             </div>
#             <div class="row">
#               <div class="col-md-12 col-xs-12">
#                 <button type="submit" id="signin-user" class="fe-input">ACESSAR</button>
#                 <div class="tooltip-success" data-toggle="tooltip" data-placement="bottom" title="Login efetuado com sucesso!" data-trigger="manual"></div>
#                 <div class="tooltip-error" data-toggle="tooltip" data-placement="bottom" title="Dados inválidos" data-trigger="manual"></div>
#               </div>
#             </div>
#             <div class="row">
#               <div class="col-md-12 col-xs-12">
#                 <div class="bottom-signin">
#                   <span>Ainda não tem conta?</span>
#                   <a id="btn-signup" class="btn" href="javascript:;">Cadastre-se</a>
#                 </div>
#               </div>
#             </div>
# </form>          <form id="form-reset-password" action="/users/password" accept-charset="UTF-8" method="post"><input name="utf8" type="hidden" value="✓"><input type="hidden" name="authenticity_token" value="cZoG2ibj3c6zdU0psShXtB6B++7ao1XfjyfPo9xcGHMUmdpjE3T9Hf0dzgkbnWCHYRabt+q4KjrS1Ps5ou0AYg==">
#             <span id="reset-password-title">Esqueceu sua senha?</span>
#             <div class="row">
#               <div class="form-group col-md-12 col-xs-12">
#                 <input autocomplete="username email" id="email-reset-password" class="fe-input signin-signup-input form-control" placeholder="Digite seu e-mail" type="email" name="user[email]">
#               </div>
#             </div>
#             <div class="row">
#               <div class="col-md-12 col-xs-12">
#                 <button type="submit" id="reset-password" class="fe-input">RESETAR SENHA</button>
#                 <div class="tooltip-success" data-toggle="tooltip" data-placement="bottom" title="E-mail com instruções para resetar senha enviado!" data-trigger="manual"></div>
#                 <div class="tooltip-error" data-toggle="tooltip" data-placement="bottom" title="Erro ao resetar senha" data-trigger="manual"></div>
#               </div>
#             </div>
# </form>        </div>
#       </div>
#       <div id="signup-container">
#         <div id="signup-wrapper" class="menu-user-actions-wrapper">
#           <div id="menu-marker-signup" class="menu-selected-marker"></div>
#           <div class="close-signin-signup-wrapper">
#             <a id="close-signup" class="close-signin-signup" href="javascript:;"><img alt="Fechar login" src="/assets/icons/fechar-b42fc0c933cfffdbf591556fc1b9f2dc2ed1601e6b39ae0c48289bcf6802b1fe.png"></a>
#           </div>
#           <span id="signup-title">Criar uma conta grátis!</span>
#           <form id="form-signup" action="/users" accept-charset="UTF-8" method="post"><input name="utf8" type="hidden" value="✓"><input type="hidden" name="authenticity_token" value="cZoG2ibj3c6zdU0psShXtB6B++7ao1XfjyfPo9xcGHMUmdpjE3T9Hf0dzgkbnWCHYRabt+q4KjrS1Ps5ou0AYg==">
#             <div class="row">
#               <div class="form-group col-md-12 col-xs-12">
#                 <input id="name-signup" autofocus="autofocus" autocomplete="name" class="fe-input signin-signup-input form-control tooltip-error name" placeholder="Seu nome" data-toggle="tooltip" data-placement="left" data-trigger="manual" type="text" name="user[name]">
#               </div>
#             </div>
#             <div class="row">
#               <div class="form-group col-md-12 col-xs-12">
#                 <input id="email-signup" autocomplete="username email" class="fe-input signin-signup-input form-control tooltip-error email" placeholder="Seu e-mail" data-toggle="tooltip" data-placement="left" data-trigger="manual" type="email" name="user[email]">
#               </div>
#             </div>
#             <div class="row">
#               <div class="form-group col-md-12 col-xs-12">
#                 <input id="password-signup" autocomplete="password" placeholder="Crie uma senha" class="fe-input signin-signup-input form-control tooltip-error password" data-toggle="tooltip" data-placement="left" data-trigger="manual" type="password" name="user[password]">
#               </div>
#             </div>
#             <div class="row">
#               <div class="checkbox col-md-12 col-xs-12">
#                 <label for="remember-me">
#                   <input type="checkbox" name="remember-me" id="remember-me"> Li e concordo com os <a target="_blank" href="/termos-de-uso"><span id="Termos de Uso">Termos de Uso</span></a>
#                 </label>
#               </div>
#             </div>
#             <div class="row">
#               <div class="col-md-12 col-xs-12">
#                 <button type="submit" id="signup-user" class="fe-input">CRIAR CONTA</button>
#                 <div class="tooltip-success" data-toggle="tooltip" data-placement="bottom" title="Conta criada! Acesse seu e-mail para confirmação." data-trigger="manual"></div>
#               </div>
#             </div>
#             <div class="row">
#               <div class="checkbox col-md-12 col-xs-12">
#                 <label for="fazer-login">
#                   <a href="javascript:;"><span id="btn-signin" name="fazer-login">Fazer Login</span></a>
#                 </label>
#               </div>
#             </div>
# </form>        </div>
#       </div>
#     </div>
#     <div id="submenu">
#       <div id="submenu-ferramentas" class="submenu-items hoverable-submenu" data-item="ferramentas">
#         <div class="container">
#           <div class="row">
#             <div class="col-md-3 col-xs-12 submenu-item">
#               <a href="/funds"><img alt="Lista Fiis" src="/assets/icons/home/lista-fiis-new-254040adc3dfaeea8f29b6be6b252d227f008c7b8ab17e37d45c8aa37fe7b906.png"><span>Lista de FIIs</span></a>
#               <p>Lista com todos os FIIs negociados na Bolsa de Valores.</p>
#             </div>
#             <div class="col-md-3 col-xs-12 submenu-item">
#               <a href="/ranking"><img alt="Ranking Fiis" src="/assets/icons/home/ranking-fiis-3f41ad795a57e41fa44fa51e029119701679c7ee3b4a4b9d7a7f6b39ba8f131a.png"><span>Ranking de FIIs</span></a>
#               <p>Conheça os melhores FIIs de acordo com cada indicador</p>
#             </div>
#             <div class="col-md-3 col-xs-12 submenu-item">
#               <a href="/rendimentos-e-amortizacoes"><img alt="Rendimentos" src="/assets/icons/home/rendimentos-02a11c877654f38f53a85f3deb5300be5a5b1a153c5876390ca970db6d7eeaf4.png"><span>Rendimentos</span></a>
#               <p>Confira as distribuições de rendimentos de cada FII.</p>
#             </div>
#             <div class="col-md-3 col-xs-12 submenu-item">
#               <a href="/mapa-fiis"><img alt="Mapa de Fiis" src="/assets/icons/home/mapa-fiis-1633afa2546c1a4909ae1fffea43f36f0a96e58952a5045aaac16f9ef4355714.png"><span>Mapa de Fiis</span></a>
#               <p>Identifique a localização exata dos ativos de cada FII.</p>
#             </div>
#           </div>
#           <div class="row">
#             <div class="col-md-3 col-xs-12 submenu-item">
#               <a href="/estudos"><img alt="Estudos" src="/assets/icons/home/estudos-new-93a29b1a9121dc8bb9cdabbca332b93a13ae435ecc028b8ffb784f45cf736939.png"><span>Estudos</span></a>
#               <p>Crie e tenha acesso a estudos personalizados por nossa equipe.</p>
#             </div>
#             <div class="col-md-3 col-xs-12 submenu-item">
#               <a href="/carteiras"><img alt="Carteiras" src="/assets/icons/home/carteiras-new-cc0498ee6e992c403ffde489ee9d97d0a2dab917195a300daf0a3de636a88c63.png"><span>Carteiras</span></a>
#               <p>Monte e acompanhe o desempenho das suas carteiras.</p>
#             </div>
#             <div class="col-md-3 col-xs-12 submenu-item">
#               <a href="/simulador"><img alt="Simulador" src="/assets/icons/home/simulador-new-120a4209228d82bb555880d9fd0d2bc6b42a0000a1fff22f5b4ee9a9afa99a6e.png"><span>Simulador</span></a>
#               <p>Compare a valorização de cada FII com benchmarks.</p>
#             </div>
#             <div class="col-md-3 col-xs-12 submenu-item">
#               <a href="/placar-fiis"><img alt="Placar de Fiis" src="/assets/icons/home/placar-new-93e02f6fa854642cbcedcc86f1ff7df7407fc781f9b54a54cd62845c9fab21da.png"><span>Placar de Fiis</span></a>
#               <p>Classifique cada FII de acordo com seus indicadores.</p>
#             </div>
#           </div>
#           <div class="row">
#             <div class="col-md-3 col-xs-12 submenu-item">
#               <a href="/comunicados"><img alt="Comunicados" src="/assets/icons/home/lista-fiis-new-254040adc3dfaeea8f29b6be6b252d227f008c7b8ab17e37d45c8aa37fe7b906.png"><span>Comunicados</span></a>
#               <p>Consulte os últimos comunicados dos FIIs.</p>
#             </div>
#           </div>
#         </div>
#       </div>
#       <div id="submenu-gratuito" class="submenu-items hoverable-submenu" data-item="gratuito">
#         <div class="container">
#           <div class="row">
#             <div class="col-md-3 col-xs-12 submenu-item-2">
#               <a target="_blank" href="https://lp.fundsexplorer.com.br/ebook-gratuito-fiis/"><img alt="Book" src="/assets/icons/home/book-788955a4482aa6dba99044f250e5bf8d7ab14e8cc5789b899e3458dc0a29b566.png"><span>Ebook grátis</span></a>
#               <p>Análise e avaliação dos Fundos Imobiliários através da ótica de dois especialistas do Funds.</p>
#             </div>
#             <div class="col-md-3 col-xs-12 submenu-item-2">
#               <a target="_blank" href="https://lp.fundsexplorer.com.br/lista-vip/"><img alt="Star" src="/assets/icons/home/star-b214c1cc959e1fc20425d6c23477c3db637d58a2d951c08a37ba539bb639bd83.png"><span>Lista VIP</span></a>
#               <p>Informações exclusivas e relevantes todos os dias gratuitamente em seu email.</p>
#             </div>
#             <div class="col-md-3 col-xs-12 submenu-item-2">
#               <a target="_blank" href="https://t.me/jfiis"><img alt="Telegram" src="/assets/icons/home/telegram-0c57681625536f05182d213fde678cf8952ef119b66904071781904c6d5a5352.png"><span>Telegram</span></a>
#               <p>Conteúdos exclusivos sobre o mercado de FIIs, com a presença de Jacinto Santos.</p>
#             </div>
#             <div class="col-md-3 col-xs-12 submenu-item-2" style="width: 366px; margin-left: -17px;">
#               <a target="_blank" href="https://lp.fundsexplorer.com.br/calculadora-de-lucro/"><img alt="Calculadora" src="/assets/icons/home/calc-1e8ac76392c15ee423197a2408098c7d67a56430d4eb489e38516a112abe8242.png"><span>Calculadora de Lucro</span></a>
#               <p>Faça o cálculo do preço médio, taxas proporcionais e do Lucro dos FIIs de sua carteira.</p>
#             </div>
#           </div>
#           <div class="row">
#             <div class="col-md-3 col-xs-12 submenu-item-2">
#               <a target="_blank" href="https://lp.fundsexplorer.com.br/fiicast/"><img alt="Placar de FIIs" style="width: 40px; height: auto;" src="/assets/icons/home/placar-8c1128524f55e2c6501a0c850f19341831c7bf71ac2db935d561a903d53279fc.png"><span>Fiicast</span></a>
#               <p>Conheça o FIICAST - Um podcast Funds Explorer.</p>
#             </div>
#           </div>
#         </div>
#       </div>
#     </div>
#     <div id="submenu-subscriber">
#       <div class="container">
#         <div class="items">
#           <a href="/area-assinante/dashboard"><span>Área do Assinante</span></a>
#           <a href="/meus-dados"><span>Meus Dados</span></a>
#           <a href="/users/sign_out"><span>Sair</span></a>
#         </div>
#       </div>
#     </div>
#     <div id="menu-mobile">
#       <button id="menu-mobile-close" class="btn"><span>×</span></button>
#       <div id="menu-mobile-first-level">
#         <ul>
#           <li>
#             <a class="menu-item has-second-level" data-item="ferramentas" href="javascript:;"><span>Ferramentas</span><img alt="Seta para a direita" class="has-second-level-icon" src="/assets/icons/seta-acesso-rapido-3a4dc9469ed73be961425e3697a12b0b4bad882014dc308677b09865d2b3912a.png"></a>
#           </li>
#           <li>
#             <a class="menu-item" href="https://lp.fundsexplorer.com.br/carteira-de-investimento-em-fiis/"><span>Assinatura</span></a>
#           </li>
#           <li>
#             <a class="menu-item" href="https://lp.fundsexplorer.com.br/funds-explorer-mentoria/"><span>Mentoria</span></a>
#           </li>
#           <li>
#             <a class="menu-item" href="https://lp.fundsexplorer.com.br/curso-fundsexplorer-learning/"><span>Curso Online</span></a>
#           </li>
#           <li>
#             <a class="menu-item has-second-level" data-item="gratuito" href="javascript:;"><span>Gratuito</span><img alt="Seta para a direita" class="has-second-level-icon" src="/assets/icons/seta-acesso-rapido-3a4dc9469ed73be961425e3697a12b0b4bad882014dc308677b09865d2b3912a.png"></a>
#           </li>
#           <li>
#             <a id="btn-my-account-mobile" class="menu-item has-second-level hidden" data-item="profile" href="#"><img class="profile" src="/assets/icons/profile-e1626371c4a19db72fe7eb8943096747b6d7a8076d88e08f202a98baf342d782.png"><span></span><img alt="Seta para a direita" class="has-second-level-icon" src="/assets/icons/seta-acesso-rapido-3a4dc9469ed73be961425e3697a12b0b4bad882014dc308677b09865d2b3912a.png"></a>
#           </li>
#           <li>
#             <a id="btn-signin-mobile" class="menu-item hidden" href="javascript:;">Entrar</a>
#           </li>
#           <li>
#             <a id="btn-signup-mobile" class="menu-item hidden" href="javascript:;">Cadastre-se</a>
#           </li>
#         </ul>
#       </div>
#
#       <div id="menu-mobile-second-level-fiis" class="menu-mobile-second-level">
#         <ul>
#           <li>
#             <a href="javascript:;" class="menu-mobile-back">
#               <img alt="Seta para a direita" class="has-second-level-icon" src="/assets/icons/seta-acesso-rapido-3a4dc9469ed73be961425e3697a12b0b4bad882014dc308677b09865d2b3912a.png">
#               voltar
#             </a>
#           </li>
#           <li>
#             <a href="/funds">Lista de FIIs</a>
#           </li>
#           <li>
#             <a href="/ranking">Ranking de FIIs</a>
#           </li>
#           <li>
#             <a href="/rendimentos-e-amortizacoes">Rendimentos</a>
#           </li>
#           <li>
#             <a href="/comunicados">Comunicados</a>
#           </li>
#         </ul>
#       </div>
#
#       <div id="menu-mobile-second-level-gratuito" class="menu-mobile-second-level">
#         <a href="javascript:;" class="menu-mobile-back">
#           <img alt="Seta para a direita" class="has-second-level-icon" src="/assets/icons/seta-acesso-rapido-3a4dc9469ed73be961425e3697a12b0b4bad882014dc308677b09865d2b3912a.png">
#           voltar
#         </a>
#         <span id="title">Gratuito</span>
#         <ul>
#           <li>
#             <a target="_blank" href="https://lp.fundsexplorer.com.br/ebook-gratuito-fiis/"><span>Ebook grátis</span></a>
#           </li>
#           <li>
#             <a target="_blank" href="https://lp.fundsexplorer.com.br/lista-vip/"><span>Lista VIP</span></a>
#           </li>
#           <li>
#             <a target="_blank" href="https://t.me/jfiis"><span>Telegram</span></a>
#           </li>
#           <li>
#             <a target="_blank" href="https://lp.fundsexplorer.com.br/ebook-gratuito-fiis/"><span>Calculadora de Lucro</span></a>
#           </li>
#           <li>
#             <a target="_blank" href="https://lp.fundsexplorer.com.br/fiicast/"><span>FIICAST - Um podcast Funds Explorer</span></a>
#           </li>
#         </ul>
#       </div>
#       <div id="menu-mobile-second-level-ferramentas" class="menu-mobile-second-level">
#         <a href="javascript:;" class="menu-mobile-back">
#           <img alt="Seta para a direita" class="has-second-level-icon" src="/assets/icons/seta-acesso-rapido-3a4dc9469ed73be961425e3697a12b0b4bad882014dc308677b09865d2b3912a.png">
#           voltar
#         </a>
#         <span id="title">Ferramentas</span>
#         <ul>
#           <li>
#             <a href="/funds"><img alt="Lista Fiis" class="img-menu-item" src="/assets/icons/home/lista-fiis-new-254040adc3dfaeea8f29b6be6b252d227f008c7b8ab17e37d45c8aa37fe7b906.png"><span>Lista de FIIs</span></a>
#           </li>
#           <li>
#             <a href="/ranking"><img alt="Ranking Fiis" class="img-menu-item" src="/assets/icons/home/ranking-fiis-3f41ad795a57e41fa44fa51e029119701679c7ee3b4a4b9d7a7f6b39ba8f131a.png"><span>Ranking de FIIs</span></a>
#           </li>
#           <li>
#             <a href="/rendimentos-e-amortizacoes"><img alt="Rendimentos" class="img-menu-item" src="/assets/icons/home/rendimentos-02a11c877654f38f53a85f3deb5300be5a5b1a153c5876390ca970db6d7eeaf4.png"><span>Rendimentos</span></a>
#           </li>
#           <li>
#             <a href="/mapa-fiis"><img alt="Mapa de Fiis" class="img-menu-item" src="/assets/icons/home/mapa-fiis-1633afa2546c1a4909ae1fffea43f36f0a96e58952a5045aaac16f9ef4355714.png"><span>Mapa de Fiis</span></a>
#           </li>
#           <li>
#             <a href="/estudos"><img alt="Estudos" class="img-menu-item" src="/assets/icons/home/estudos-new-93a29b1a9121dc8bb9cdabbca332b93a13ae435ecc028b8ffb784f45cf736939.png"><span>Estudos</span></a>
#           </li>
#           <li>
#             <a href="/carteiras"><img alt="Carteiras" class="img-menu-item" src="/assets/icons/home/carteiras-new-cc0498ee6e992c403ffde489ee9d97d0a2dab917195a300daf0a3de636a88c63.png"><span>Carteiras</span></a>
#           </li>
#           <li>
#             <a href="/simulador"><img alt="Simulador" class="img-menu-item" src="/assets/icons/home/simulador-new-120a4209228d82bb555880d9fd0d2bc6b42a0000a1fff22f5b4ee9a9afa99a6e.png"><span>Simulador</span></a>
#           </li>
#           <li>
#             <a href="/placar-fiis"><img alt="Placar de Fiis" class="img-menu-item" src="/assets/icons/home/placar-new-93e02f6fa854642cbcedcc86f1ff7df7407fc781f9b54a54cd62845c9fab21da.png"><span>Placar de Fiis</span></a>
#           </li>
#           <li>
#             <a href="/comunicados"><img alt="Comunicados" class="img-menu-item" src="/assets/icons/home/lista-fiis-new-254040adc3dfaeea8f29b6be6b252d227f008c7b8ab17e37d45c8aa37fe7b906.png"><span>Comunicados</span></a>
#           </li>
#         </ul>
#       </div>
#       <div id="menu-mobile-second-level-profile" class="menu-mobile-second-level">
#         <a href="javascript:;" class="menu-mobile-back">
#           <img alt="Seta para a direita" class="has-second-level-icon" src="/assets/icons/seta-acesso-rapido-3a4dc9469ed73be961425e3697a12b0b4bad882014dc308677b09865d2b3912a.png">
#           voltar
#         </a>
#         <span id="title">Perfil</span>
#         <ul>
#           <li>
#             <a class="hidden subscriber" href="/area-assinante/dashboard"><span>Área do Assinante</span></a>
#           </li>
#           <li>
#             <a href="/meus-dados"><span>Meus Dados</span></a>
#           </li>
#           <li>
#             <a href="/users/sign_out"><span>Sair</span></a>
#           </li>
#         </ul>
#       </div>
#     </div>
#   </div>
#   <div id="search-menu" style="">
#     <div class="container">
#       <div class="row">
#         <div class="col-md-7 col-xs-12 justify-content-center">
#           <div class="form-group">
#             <select name="search-menu-select" id="search-menu-select" class="form-control fe-input select2-hidden-accessible" multiple="" tabindex="-1" aria-hidden="true"><option value="ABCP11">ABCP11 - FDO INV IMOB GRAND PLAZA SHOPPING</option>
# <option value="AFOF11">AFOF11 - ALIANZA FOFII FDO. INVEST. IMOB.</option>
# <option value="ALMI11">ALMI11 - FDO INV IMOB - FII TORRE ALMIRANTE</option>
# <option value="ALZR11">ALZR11 - ALIANZA TRUST RENDA IMOBILIARIA FDO INV IMOB</option>
# <option value="ANCR11B">ANCR11B - FDO INV IMOB - FII ANCAR IC</option>
# <option value="AQLL11">AQLL11 - ÁQUILLA FDO INV IMOB - FII</option>
# <option value="ARFI11B">ARFI11B - ÁQUILLA RENDA FDO INV IMOB - FII</option>
# <option value="ARRI11">ARRI11 - FDO. INV. IMOB. ÁTRIO REIT RECEBÍVEIS IMOBILIÁRIOS</option>
# <option value="ATCR11">ATCR11 - ÁTICO RENDA FDO INV IMOB - FII</option>
# <option value="ATSA11">ATSA11 - HEDGE ATRIUM SHOPPING SANTO ANDRE FDO INV IMOB</option>
# <option value="BARI11">BARI11 - FDO INV IMOB BARIGUI RENDIMENTOS IMOB I FII</option>
# <option value="BBFI11B">BBFI11B - BB FDO INV IMOB PROGRESSIVO</option>
# <option value="BBPO11">BBPO11 - BB PROGRESSIVO II FDO INV IMOB - FII</option>
# <option value="BBRC11">BBRC11 - BB RENDA CORPORATIVA FDO INV IMOB - FII</option>
# <option value="BBVJ11">BBVJ11 - FDO INV IMOB BB VOTORANTIM JHSF C JARD CONT TOWER</option>
# <option value="BCFF11">BCFF11 - FDO INV IMOB - FII BTG PACTUAL FUNDO DE FUNDOS</option>
# <option value="BCIA11">BCIA11 - BRADESCO CARTEIRA IMOBILIÁRIA ATIVA - FII</option>
# <option value="BCRI11">BCRI11 - BANESTES RECEBÍVEIS IMOBILIÁRIOS FDO INV IMOB  FII</option>
# <option value="BICR11">BICR11 - INTER TÍTULOS IMOB. FDO INV. IMOB.</option>
# <option value="BMII11">BMII11 - FDO BRASÍLIO MACHADO DE INVESTIMENTO IMOBILIÁRIO</option>
# <option value="BMLC11B">BMLC11B - FDO INV IMOB BM BRASCAN LAJES CORPORATIVAS - FII</option>
# <option value="BNFS11">BNFS11 - BANRISUL NOVAS FRONTEIRAS FDO INV IMOB - FII</option>
# <option value="BPFF11">BPFF11 - FDO INV IMOB BRASIL PLURAL ABSOLUTO FDO DE FUNDOS</option>
# <option value="BPML11">BPML11 - FDO INV IMOB BTG PACTUAL SHOPPINGS</option>
# <option value="BRCO11">BRCO11 - BRESCO LOGÍSTICA - FDO INV IMOB</option>
# <option value="BRCR11">BRCR11 - FDO INV IMOB - FII BTG PACTUAL CORP. OFFICE FUND</option>
# <option value="BRHT11B">BRHT11B - FDO INV IMOB BR HOTEIS - FII</option>
# <option value="BTCR11">BTCR11 - FDO INV IMOB BTG PACTUAL CREDITO IMOBILIARIO</option>
# <option value="BTGM11">BTGM11 - FDO INV IMOB - FII BTG PACTUAL MALLS</option>
# <option value="BTLG11">BTLG11 - BTG PACTUAL LOGISTICA FDO INV IMOB - FII</option>
# <option value="BVAR11">BVAR11 - FDO INV IMOB BRASIL VAREJO - FII</option>
# <option value="BZLI11">BZLI11 - BRAZIL REALTY FDO INV IMOB</option>
# <option value="CARE11">CARE11 - BRAZILIAN GRAVEYARD DEATH CARE FDO INV IMOB - FII</option>
# <option value="CBOP11">CBOP11 - CASTELLO BRANCO OFFICE PARK FDO INV IMOB - FII</option>
# <option value="CEOC11">CEOC11 - FDO INV IMOB - FII CEO CYRELA COMMERC. PROPERTIES</option>
# <option value="CNES11">CNES11 - FDO INV IMOB - FII CENESP</option>
# <option value="CPFF11">CPFF11 - CAPITÂNIA REIT FOF - FDO. INVEST. IMOB</option>
# <option value="CPTS11B">CPTS11B - CAPITANIA SECURITIES II FDO INV IMOB - FII</option>
# <option value="CRFF11">CRFF11 - CAIXA RIO BRAVO FDO DE FDOS INV IMOB II</option>
# <option value="CTXT11">CTXT11 - FDO INV IMOB CENTRO TEXTIL INTERNACIONAL</option>
# <option value="CVBI11">CVBI11 - FDO INV. IMOB. VBI CRI</option>
# <option value="CXCE11B">CXCE11B - FDO INV IMOB CAIXA CEDAE</option>
# <option value="CXRI11">CXRI11 - CAIXA RIO BRAVO FUNDO DE FDO INV IMOB - FII</option>
# <option value="CXTL11">CXTL11 - FDO INV IMOB CAIXA TRX LOGÍSTICA RENDA</option>
# <option value="DMAC11">DMAC11 - MAC FDO INV IMOB</option>
# <option value="DOMC11">DOMC11 - REAG RENDA IMOBILIARIA FDO INV IMOB - FII</option>
# <option value="DOVL11B">DOVL11B - DOVEL FDO INV IMOB</option>
# <option value="DRIT11B">DRIT11B - MULTIGESTÃO RENDA COMERCIAL FDO INV IMOB - FII</option>
# <option value="EDFO11B">EDFO11B - FDO INV IMOB EDIFÍCIO OURINVEST</option>
# <option value="EDGA11">EDGA11 - FDO INV IMOB - FII EDIFÍCIO GALERIA</option>
# <option value="ELDO11B">ELDO11B - FDO INV IMOB - FII ELDORADO</option>
# <option value="EURO11">EURO11 - FDO INV IMOB EUROPAR</option>
# <option value="FAED11">FAED11 - FDO INV IMOB - FII ANHANGUERA EDUCACIONAL</option>
# <option value="FAMB11B">FAMB11B - FDO INV IMOB - FII EDIFÍCIO ALMIRANTE BARROSO</option>
# <option value="FCAS11">FCAS11 - FDO INV IMOB - FII EDIFÍCIO CASTELO</option>
# <option value="FCFL11">FCFL11 - FDO INV IMOB - FII CAMPUS FARIA LIMA</option>
# <option value="FEXC11">FEXC11 - FDO INV IMOB - FII BTG PACTUAL FUNDO DE CRI</option>
# <option value="FFCI11">FFCI11 - FDO INV IMOB RIO BRAVO RENDA CORPORATIVA</option>
# <option value="FIGS11">FIGS11 - FDO INV IMOB GENERAL SHOPPING ATIVO E RENDA - FII</option>
# <option value="FIIB11">FIIB11 - FDO INV IMOB INDUSTRIAL DO BRASIL</option>
# <option value="FIIP11B">FIIP11B - RB CAPITAL RENDA I FDO INV IMOB - FII</option>
# <option value="FINF11">FINF11 - FDO INV IMOB INFRA REAL ESTATE - FII</option>
# <option value="FIVN11">FIVN11 - FDO INV IMOB VIDA NOVA - FII</option>
# <option value="FLMA11">FLMA11 - FDO INV IMOB CONTINENTAL SQUARE FARIA LIMA</option>
# <option value="FLRP11">FLRP11 - FDO INV IMOB - FII FLORIPA SHOPPING</option>
# <option value="FMOF11">FMOF11 - FDO INV IMOB MEMORIAL OFFICE</option>
# <option value="FOFT11">FOFT11 - CSHG TOP FOFII 2 FDO INV IMOB - FII</option>
# <option value="FPAB11">FPAB11 - FDO INV IMOB PROJETO ÁGUA BRANCA</option>
# <option value="FPNG11">FPNG11 - FDO INV IMOB PEDRA NEGRA RENDA IMOB</option>
# <option value="FVBI11">FVBI11 - FDO INV IMOB VBI FL 4440 - FII</option>
# <option value="FVPQ11">FVPQ11 - FDO INV IMOB VIA PARQUE SHOPPING - FII</option>
# <option value="GGRC11">GGRC11 - GGR COVEPI RENDA FDO INV IMOB</option>
# <option value="GRLV11">GRLV11 - CSHG GR LOUVEIRA FDO DE INV IMOB - FII</option>
# <option value="GSFI11">GSFI11 - GENERAL SHOP E OUTLETS DO BRASIL FDO INV IMOB - FI</option>
# <option value="GTWR11">GTWR11 - FDO INV IMOB GREEN TOWERS</option>
# <option value="HABT11">HABT11 - HABITAT II - FDO INT IMOB</option>
# <option value="HBTT11">HBTT11 - FDO INV IMOB HABITAT I</option>
# <option value="HCRI11">HCRI11 - FDO INV IMOB - FII HOSPITAL DA CRIANÇA</option>
# <option value="HCTR11">HCTR11 - HECTARE CE - FDO INV IMOB</option>
# <option value="HFOF11">HFOF11 - HEDGE TOP FOFII 3 FDO INV IMOB</option>
# <option value="HGBS11">HGBS11 - HEDGE BRASIL SHOPPING FDO INV IMOB</option>
# <option value="HGCR11">HGCR11 - CSHG RECEBÍVEIS IMOBILIÁRIOS FDO INV IMOB - FII</option>
# <option value="HGFF11">HGFF11 - CSHG IMOB. FOF - FDO INV. IMOB. - FII</option>
# <option value="HGLG11">HGLG11 - CSHG LOGÍSTICA FDO INV IMOB - FII</option>
# <option value="HGPO11">HGPO11 - CSHG PRIME OFFICES FDO INV IMOB - FII</option>
# <option value="HGRE11">HGRE11 - CSHG REAL ESTATE FDO INV IMOB - FII</option>
# <option value="HGRU11">HGRU11 - CSHG RENDA URBANA - FDO INV IMOB - FII</option>
# <option value="HLOG11">HLOG11 - HEDGE LOGÍSTICA FDO. INV. IMOB.</option>
# <option value="HMOC11">HMOC11 - HEDGE SHOPPING PRAÇA DA MOÇA FDO INV IMOB</option>
# <option value="HOSI11">HOSI11 - FDO. INV. IMOB. HOUSI</option>
# <option value="HPDP11">HPDP11 - HEDGE SHOPPING PARQUE DOM PEDRO FDO. DE INV. IMOB.</option>
# <option value="HRDF11">HRDF11 - HEDGE REALTY DEVELOPMENT FDO INV IMOB</option>
# <option value="HSML11">HSML11 - HSI MALL FDO INV IMOB</option>
# <option value="HTMX11">HTMX11 - FDO INV IMOB - FII HOTEL MAXINVEST</option>
# <option value="HUSC11">HUSC11 - FDO INV IMOB HOSPITAL UNIMED SUL CAPIXABA</option>
# <option value="IBFF11">IBFF11 - FDO INV. IMOB. FOF INTEGRAL BREI</option>
# <option value="IRDM11">IRDM11 - FII IRIDIUM RECEBÍVEIS IMOBILIÁRIOS</option>
# <option value="JRDM11">JRDM11 - FDO INV IMOB - FII SHOPPING JARDIM SUL</option>
# <option value="JSRE11">JSRE11 - JS REAL ESTATE MULTIGESTÃO - FII</option>
# <option value="KFOF11">KFOF11 - FUNDO DE FDO INV IMOB KINEA FII</option>
# <option value="KINP11">KINP11 - EVEN PERMUTA KINEA FII - FDO INV IMOB</option>
# <option value="KNCR11">KNCR11 - KINEA RENDIMENTOS IMOBILIÁRIOS FDO INV IMOB - FII</option>
# <option value="KNHY11">KNHY11 - KINEA HIGH YIELD CRI FDO INV IMOB - FII</option>
# <option value="KNIP11">KNIP11 - KINEA ÍNDICES DE PREÇOS FDO INV IMOB - FII</option>
# <option value="KNRE11">KNRE11 - KINEA II REAL ESTATE EQUITY FDO INV IMOB</option>
# <option value="KNRI11">KNRI11 - KINEA RENDA IMOBILIÁRIA FDO INV IMOB - FII</option>
# <option value="LASC11">LASC11 - LEGATUS SHOPPINGS FDO. INV. IMOB. - FII</option>
# <option value="LGCP11">LGCP11 - LOGCP INTER FDO INV IMOB</option>
# <option value="LUGG11">LUGG11 - LUGGO FDO. INV. IMOB.</option>
# <option value="LVBI11">LVBI11 - FDO INV IMOB - VBI LOGÍSTICO</option>
# <option value="MALL11">MALL11 - MALLS BRASIL PLURAL FDO INV IMOB</option>
# <option value="MAXR11">MAXR11 - FDO INV IMOB - FII MAX RETAIL</option>
# <option value="MBRF11">MBRF11 - FDO INV IMOB MERCANTIL DO BRASIL - FII</option>
# <option value="MCCI11">MCCI11 - FDO INV. MAUA CAPITAL RECEBIVEIS IMOB. - FII</option>
# <option value="MFII11">MFII11 - MÉRITO DESENVOLVIMENTO IMOBILIÁRIO I - FII</option>
# <option value="MGFF11">MGFF11 - FDO INV IMOB MOGNO FUNDO DE FUNDOS</option>
# <option value="MGHT11">MGHT11 - FDO. INV. IMOB. MOGNO HOTEIS</option>
# <option value="MORE11">MORE11 - MORE REAL ESTATE FOF FII FDO. INV. IMOB.</option>
# <option value="MXRF11">MXRF11 - MAXI RENDA FDO INV IMOB - FII</option>
# <option value="NCHB11">NCHB11 - FDO INV IMOB - FII NCH BRASIL RECEBÍVEIS IMOB</option>
# <option value="NCHB11B">NCHB11B - FDO INV IMOB - FII NCH BRASIL RECEBÍVEIS IMOB</option>
# <option value="NEWL11">NEWL11 - NEWPORT LOGÍSTICA FDO INV. IMOB.</option>
# <option value="NEWU11">NEWU11 - NEWPORT RENDA URBANA FDO INV IMOB</option>
# <option value="NSLU11">NSLU11 - FDO INV IMOB - FII HOSPITAL NOSSA SRA DE LOURDES</option>
# <option value="NVHO11">NVHO11 - FDO INV IMOB - FII NOVO HORIZONTE</option>
# <option value="NVIF11B">NVIF11B - NOVA I - FDO INV IMOB - FII</option>
# <option value="ONEF11">ONEF11 - FDO INV IMOB THE ONE</option>
# <option value="ORPD11">ORPD11 - OURO PRETO DESENV IMOB I FDO INV IMOB - FII</option>
# <option value="OUCY11">OUCY11 - FUNDO INV IMOB - OURINVEST CYRELA - FII</option>
# <option value="OUFF11">OUFF11 - FDO INV IMOB - OURINVEST FUNDO DE FUNDOS</option>
# <option value="OUJP11">OUJP11 - OURINVEST JPP FDO INV IMOB - FII</option>
# <option value="OULG11">OULG11 - FDO INV IMOB OURINVEST LOGÍSTICA</option>
# <option value="PABY11">PABY11 - FDO INV IMOB PANAMBY</option>
# <option value="PATC11">PATC11 - PÁTRIA EDIFÍCIOS CORPORATIVOS FDO INV IMOB - FII</option>
# <option value="PLCR11">PLCR11 - FDO INV. IMOB. PLURAL RECEBIVEIS</option>
# <option value="PLRI11">PLRI11 - POLO FDO INV IMOB - FII RECEBÍVEIS IMOBILIÁRIOS I</option>
# <option value="PORD11">PORD11 - POLO FDO INV IMOB - RECEBÍVEIS IMOB II - FII</option>
# <option value="PQDP11">PQDP11 - FDO INV IMOB - FII PARQUE D. PEDRO SHOPPING CENTER</option>
# <option value="PRSV11">PRSV11 - FDO INV IMOB - FII PRESIDENTE VARGAS</option>
# <option value="PRTS11">PRTS11 - MULTI PROPERTIES FDO INV IMOB - FII</option>
# <option value="QAGR11">QAGR11 - QUASAR AGRO - FDO INV. IMOB.</option>
# <option value="RBBV11">RBBV11 - JHSF RIO BRAVO FAZENDA BOA VISTA CAP. PROT. - FII</option>
# <option value="RBCB11">RBCB11 - RIO BRAVO CRÉDITO IMOBILIÁRIO I FDO INV IMOB</option>
# <option value="RBCO11">RBCO11 - RB CAPITAL OFFICE INCOME FDO INV. IMOB.</option>
# <option value="RBDS11">RBDS11 - RB CAPITAL DESENV. RESID. II FDO INV IMOB - FII</option>
# <option value="RBED11">RBED11 - FUNDO DE INVESTIMENTO IMOBILIÁRIO RIO BRAVO RENDA EDUCACIONAL</option>
# <option value="RBFF11">RBFF11 - RIO BRAVO IFIX FDO INV IMOB</option>
# <option value="RBGS11">RBGS11 - RB CAPITAL GENERAL SHOP SULACAP FDO INV IMOB - FII</option>
# <option value="RBIV11">RBIV11 - RIO BRAVO CRÉDITO IMOB IV FDO INV IMOB - FII</option>
# <option value="RBRD11">RBRD11 - RB CAPITAL RENDA II FDO INV IMOB - FII</option>
# <option value="RBRF11">RBRF11 - RBR ALPHA MULTIESTRATÉGIA REAL ESTATE FDO INV IMOB</option>
# <option value="RBRP11">RBRP11 - FDO INV IMOB RBR PROPERTIES - FII</option>
# <option value="RBRR11">RBRR11 - FDO INV IMOB - FII RBR RENDIMENTO HIGH GRADE</option>
# <option value="RBRY11">RBRY11 - FDO INV IMOB RBR PRIVATE CRÉDITO IMOB</option>
# <option value="RBVA11">RBVA11 - FDO INV IMOB RIO BRAVO RENDA VAREJO - FII</option>
# <option value="RBVO11">RBVO11 - RIO BRAVO CRÉDITO IMOBILIÁRIO II FDO INV IMOB -FII</option>
# <option value="RCFA11">RCFA11 - GRUPO RCFA FDO INV IMOB</option>
# <option value="RCRB11">RCRB11 - FDO INV IMOB RIO BRAVO RENDA CORPORATIVA</option>
# <option value="RDES11">RDES11 - RENDA DE ESCRITÓRIOS FDO INV IMOB - FII</option>
# <option value="RDPD11">RDPD11 - BB RENDA DE PAPEIS IMOB II FDO INV IMOB - FII</option>
# <option value="RECT11">RECT11 - FDO INV IMOB - FII UBS (BR) OFFICE</option>
# <option value="RFOF11">RFOF11 - FDO. INVEST. IMOB. RB CAPITAL I FUNDO DE FUNDOS</option>
# <option value="RNDP11">RNDP11 - BB RENDA DE PAPÉIS IMOBILIÁRIOS FDO INV IMOB - FII</option>
# <option value="RNGO11">RNGO11 - FDO INV IMOB RIO NEGRO - FII</option>
# <option value="RVBI11">RVBI11 - VBI REITS FOF - FDO. INV. IMOB</option>
# <option value="SAAG11">SAAG11 - SANTANDER AGÊNCIAS FDO INV IMOB - FII</option>
# <option value="SADI11">SADI11 - SANTANDER PAPEIS IMOB CDI FDO INV IMOB</option>
# <option value="SAIC11B">SAIC11B - FDO INV IMOB - FII SIA CORPORATE</option>
# <option value="SARE11">SARE11 - SANTANDER RENDA DE ALUGUÉIS FDO. INVEST. IMOB.</option>
# <option value="SCPF11">SCPF11 - FDO INV IMOB SCP</option>
# <option value="SDIL11">SDIL11 - SDI LOGÍSTICA RIO FDO INV IMOB - FII</option>
# <option value="SDIP11">SDIP11 - SDI PROPERTIES - FDO INV. IMOB</option>
# <option value="SFND11">SFND11 - FDO INV IMOB SÃO FERNANDO</option>
# <option value="SHDP11B">SHDP11B - FDO INV IMOB - FII SHOPPING PARQUE D. PEDRO</option>
# <option value="SHOP11">SHOP11 - MULTI SHOPPINGS FDO INV IMOB - FII</option>
# <option value="SHPH11">SHPH11 - FDO INV IMOB SHOPPING PÁTIO HIGIENÓPOLIS</option>
# <option value="SPTW11">SPTW11 - SP DOWNTOWN FDO INV IMOB - FII</option>
# <option value="TBOF11">TBOF11 - FDO INV IMOB - FII TB OFFICE</option>
# <option value="TEPP11">TEPP11 - TELLUS PROPERTIES - FDO INV. IMOB</option>
# <option value="TFOF11">TFOF11 - HEDGE TOP FOFII FDO INV IMOB</option>
# <option value="TGAR11">TGAR11 - FDO INV IMOB TG ATIVO REAL</option>
# <option value="THRA11">THRA11 - FDO INV IMOB - FII CYRELA THERA CORPORATE</option>
# <option value="TORD11">TORD11 - TORDESILHAS EI FDO. INV. IMOB.</option>
# <option value="TRNT11">TRNT11 - FDO INV IMOB - FII TORRE NORTE</option>
# <option value="TRXF11">TRXF11 - TRX REAL ESTATE FDO. INV. IMOB. - FII</option>
# <option value="TRXL11">TRXL11 - TRX REALTY LOGÍSTICA RENDA I FDO INV IMOB - FII</option>
# <option value="UBSR11">UBSR11 - FDO INV IMOB - FII UBS (BR) RECEB IMOB</option>
# <option value="VCJR11">VCJR11 - VECTIS JUROS REAL FDO INV. IMOB. - FII</option>
# <option value="VERE11">VERE11 - FDO INV IMOB VEREDA - FII</option>
# <option value="VGIP11">VGIP11 - VALORA CRI ÍNDICE DE PREÇO FDO INVEST. IMOB. FII</option>
# <option value="VGIR11">VGIR11 - VALORA RE III FDO INV IMOB - FII</option>
# <option value="VIFI11">VIFI11 - VINCI INSTRUMENTOS FINANCEIROS FDO INV IMOB - FII</option>
# <option value="VILG11">VILG11 - VINCI LOGÍSTICA FDO INV IMOB - FII</option>
# <option value="VINO11">VINO11 - VINCI OFFICES FDO INV IMOB</option>
# ...
#
#                         <td data-valor="0.0" data-order="0.0">R$ 0,00</td>
#
#                         <td data-valor="0.0" data-order="0.0">0,00%</td>
#
#                         <td data-valor="0.3584229390681" data-order="0.3584229390681">0,36%</td>
#
#                         <td data-valor="0.3584229390681" data-order="0.3584229390681">0,36%</td>
#
#                         <td data-valor="0.3584229390681" data-order="0.3584229390681">0,36%</td>
#
#                         <td data-order="0.1194743130227">0,12%</td>
#
#                         <td data-order="0.0597371565113501">0,06%</td>
#
#                         <td data-order="0.029868578255675">0,03%</td>
#
#                         <td data-order="0.3584229390681">0,36%</td>
#
#                         <td data-order="-51.0394265232975">-51,04%</td>
#
#                         <td data-order="-51.0394265232975">-51,04%</td>
#
#                         <td data-order="-50.8639405968577">-50,86%</td>
#
#                         <td data-order="1977382284.24">R$ 1.977.382.284,24</td>
#
#                         <td data-order="108.601533">R$ 108,60</td>
#
#                         <td data-order="0.9438172479572641">0,94</td>
#
#                         <td data-order="0.0">0,00%</td>
#
#                         <td data-order="0.0125769105199236">0,01%</td>
#
#                         <td data-order="0.0125769105199236">0,01%</td>
#
#                         <td data-order="0.774682567902718">0,77%</td>
#
#                         <td data-order="4.1">4,10%</td>
#
#                         <td data-order="-9999999999">N/A</td>
#
#                         <td data-order="13">13</td>
#                       </tr><tr role="row" class="odd">
#                         <td data-index="XPPR11" class="sorting_1"><a href="/funds/xppr11">XPPR11</a></td>
#
#                         <td>Outros</td>
#
#                         <td data-order="94.39">R$ 94,39</td>
#
#                         <td data-order="8407.0">8407.0</td>
#
#                         <td data-valor="0.8" data-order="0.8">R$ 0,80</td>
#
#                         <td data-valor="1.00426813959327" data-order="1.00426813959327">1,00%</td>
#
#                         <td data-valor="2.27963116503553" data-order="2.27963116503553">2,28%</td>
#
#                         <td data-valor="0.0" data-order="0.0">0,00%</td>
#
#                         <td data-valor="0.0" data-order="0.0">0,00%</td>
#
#                         <td data-order="0.759877055011842">0,76%</td>
#
#                         <td data-order="0.0">0,00%</td>
#
#                         <td data-order="0.0">0,00%</td>
#
#                         <td data-order="3.27237014332165">3,27%</td>
#
#                         <td data-order="4.54068241469816">4,54%</td>
#
#                         <td data-order="5.59055118110237">5,59%</td>
#
#                         <td data-order="-23.7959172258027">-23,80%</td>
#
#                         <td data-order="425418987.86">R$ 425.418.987,86</td>
#
#                         <td data-order="98.476618">R$ 98,48</td>
#
#                         <td data-order="0.9585016414759492">0,96</td>
#
#                         <td data-order="0.812375583410064">0,81%</td>
#
#                         <td data-order="2.72088899763083">2,72%</td>
#
#                         <td data-order="3.55536841890935">3,56%</td>
#
#                         <td data-order="5.59106830468723">5,59%</td>
#
#                         <td data-order="9.0">9,00%</td>
#
#                         <td data-order="-9999999999">N/A</td>
#
#                         <td data-order="4">4</td>
#                       </tr><tr role="row" class="even">
#                         <td data-index="XPSF11" class="sorting_1"><a href="/funds/xpsf11">XPSF11</a></td>
#
#                         <td>Outros</td>
#
#                         <td data-order="96.16">R$ 96,16</td>
#
#                         <td data-order="8454.0">8454.0</td>
#
#                         <td data-valor="0.675" data-order="0.675">R$ 0,68</td>
#
#                         <td data-valor="0.728941684665227" data-order="0.728941684665227">0,73%</td>
#
#                         <td data-valor="2.27783493723965" data-order="2.27783493723965">2,28%</td>
#
#                         <td data-valor="0.0" data-order="0.0">0,00%</td>
#
#                         <td data-valor="0.0" data-order="0.0">0,00%</td>
#
#                         <td data-order="0.759278312413216">0,76%</td>
#
#                         <td data-order="0.0">0,00%</td>
#
#                         <td data-order="0.0">0,00%</td>
#
#                         <td data-order="2.98972347583418">2,99%</td>
#
#                         <td data-order="7.05202312138729">7,05%</td>
#
#                         <td data-order="7.83236994219652">7,83%</td>
#
#                         <td data-order="-2.98010955788546">-2,98%</td>
#
#                         <td data-order="320375147.41">R$ 320.375.147,41</td>
#
#                         <td data-order="95.634372">R$ 95,63</td>
#
#                         <td data-order="1.005496224725562">1,01</td>
#
#                         <td data-order="0.705813177713971">0,71%</td>
#
#                         <td data-order="0.971904381792377">0,97%</td>
#
#                         <td data-order="1.68457738870782">1,68%</td>
#
#                         <td data-order="-3.45647276972706">-3,46%</td>
#
#                         <td data-order="-9999999999">N/A</td>
#
#                         <td data-order="-9999999999">N/A</td>
#
#                         <td data-order="0">0</td>
#                       </tr><tr role="row" class="odd">
#                         <td data-index="XTED11" class="sorting_1"><a href="/funds/xted11">XTED11</a></td>
#
#                         <td>Lajes Corporativas</td>
#
#                         <td data-order="8.95">R$ 8,95</td>
#
#                         <td data-order="3321.0">3321.0</td>
#
#                         <td data-valor="0.0" data-order="0.0">R$ 0,00</td>
#
#                         <td data-valor="0.0" data-order="0.0">0,00%</td>
#
#                         <td data-valor="0.0" data-order="0.0">0,00%</td>
#
#                         <td data-valor="0.0" data-order="0.0">0,00%</td>
#
#                         <td data-valor="0.0" data-order="0.0">0,00%</td>
#
#                         <td data-order="0.0">0,00%</td>
#
#                         <td data-order="0.0">0,00%</td>
#
#                         <td data-order="0.0">0,00%</td>
#
#                         <td data-order="0.0">0,00%</td>
#
#                         <td data-order="1.09622411693058">1,10%</td>
#
#                         <td data-order="1.09622411693058">1,10%</td>
#
#                         <td data-order="-37.8277153558052">-37,83%</td>
#
#                         <td data-order="26471845.31">R$ 26.471.845,31</td>
#
#                         <td data-order="14.767645">R$ 14,77</td>
#
#                         <td data-order="0.6060546552954109">0,61</td>
#
#                         <td data-order="-9999999999">N/A</td>
#
#                         <td data-order="-9999999999">N/A</td>
#
#                         <td data-order="-9999999999">N/A</td>
#
#                         <td data-order="-9999999999">N/A</td>
#
#                         <td data-order="100.0">100,00%</td>
#
#                         <td data-order="100.0">100,00%</td>
#
#                         <td data-order="1">1</td>
#                       </tr><tr role="row" class="even">
#                         <td data-index="YCHY11" class="sorting_1"><a href="/funds/ychy11">YCHY11</a></td>
#
#                         <td>Outros</td>
#
#                         <td data-order="1000.0">R$ 1.000,00</td>
#
#                         <td data-order="2.0">2.0</td>
#
#                         <td data-valor="10.14" data-order="10.14">R$ 10,14</td>
#
#                         <td data-valor="0.930275229357798" data-order="0.930275229357798">0,93%</td>
#
#                         <td data-valor="0.0" data-order="0.0">0,00%</td>
#
#                         <td data-valor="0.0" data-order="0.0">0,00%</td>
#
#                         <td data-valor="0.0" data-order="0.0">0,00%</td>
#
#                         <td data-order="0.0">0,00%</td>
#
#                         <td data-order="0.0">0,00%</td>
#
#                         <td data-order="0.0">0,00%</td>
#
#                         <td data-order="2.00462077909602">2,00%</td>
#
#                         <td data-order="14.1361256544503">14,14%</td>
#
#                         <td data-order="15.1979057591623">15,20%</td>
#
#                         <td data-order="16.4355293330775">16,44%</td>
#
#                         <td data-order="23653641.23">R$ 23.653.641,23</td>
#
#                         <td data-order="1014.338553">R$ 1.014,34</td>
#
#                         <td data-order="0.9858641348516307">0,99</td>
#
#                         <td data-order="0.999666232739554">1,00%</td>
#
#                         <td data-order="0.161943551231691">0,16%</td>
#
#                         <td data-order="1.16322867896901">1,16%</td>
#
#                         <td data-order="3.16377726602886">3,16%</td>
#
#                         <td data-order="-9999999999">N/A</td>
#
#                         <td data-order="-9999999999">N/A</td>
#
#                         <td data-order="2">2</td>
#                       </tr></tbody>
#                   </table></div>
#                 </div></div></div><div class="simplebar-placeholder" style="width: 3511px; height: 10910px;"></div></div><div class="simplebar-track horizontal" style="visibility: visible;"><div class="simplebar-scrollbar" style="width: 131px; transform: translate3d(0px, 0px, 0px);"></div></div><div class="simplebar-track vertical" style="visibility: visible;"><div class="simplebar-scrollbar" style="height: 32px; transform: translate3d(0px, 0px, 0px);"></div></div></div>
#               </div>
#             </div>
#           </div>
#         </div>
#       </div>
#     </section>
#   </div>
# </section>
# <script type="text/javascript" id="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","428828484703522");fbq("track","PageView");</script>
# <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=428828484703522&amp;ev=PageView&amp;noscript=1"></noscript>
# <script type="text/javascript" id="hotmart_launcher_script">(function(a,e,f,g,b,c,d,h){a.HotmartLauncherObject=b;a[b]=a[b]||function(){(a[b].q=a[b].q||[]).push(arguments)};a[b].l=1*new Date;c=e.createElement(f);d=e.getElementsByTagName(f)[0];c.async=1;c.src=g;d.parentNode.insertBefore(c,d)})(window,document,"script","//launcher.hotmart.com/launcher.js","hot");hot("account","ea65c2cd-8a92-492b-94cd-88032dc5e373");</script><script type="text/javascript" id="">(function(a,d,e,f,g,b,c){a.visitorGlobalObjectAlias=f;a[a.visitorGlobalObjectAlias]=a[a.visitorGlobalObjectAlias]||function(){(a[a.visitorGlobalObjectAlias].q=a[a.visitorGlobalObjectAlias].q||[]).push(arguments)};a[a.visitorGlobalObjectAlias].l=(new Date).getTime();b=d.createElement("script");b.src=e;b.async=!0;c=d.getElementsByTagName("script")[0];c.parentNode.insertBefore(b,c)})(window,document,"https://diffuser-cdn.app-us1.com/diffuser/diffuser.js","vgo");vgo("setAccount","649580125");
# vgo("setTrackByDefault",!0);vgo("process");</script>
#
#     <div class="modal fade" id="modal-response" tabindex="-1" role="dialog">
#   <div class="modal-dialog" role="document">
#     <div class="modal-content">
#       <div class="modal-body">
#         <img alt="Confirmar" class="confirm hidden" src="/assets/icons/modal-confirm-96a52b33487908369c8e4267957e43f60456ea2c0e48851925147f5e48ba934c.png">
#         <img alt="Cancelar" class="cancel hidden" src="/assets/icons/modal-cancel-fb46fcdb038a32bc8dfd18f002568f3985b856f1d08993e062e2eb667d4486ab.png">
#         <span class="modal-title"></span>
#         <p class="modal-description"></p>
#       </div>
#       <div class="modal-footer">
#         <button type="button" class="btn btn-default modal-btn-cancel" data-dismiss="modal">Cancelar</button>
#         <button type="button" class="btn btn-primary modal-btn-action"></button>
#       </div>
#     </div>
#   </div>
# </div>
#     <footer>
#   <div class="container">
#     <div class="row">
#       <div class="col-md-12 col-xs-12">
#         <div id="social-media-links">
#           <a href="https://www.facebook.com/fundsexplorer/"><img alt="Logo do Facebook" src="/assets/icons/facebook-569c8e830c0095155bb154859a1153e00bfbda7472ca5e2f5abb5f0102343d32.png"></a>
#           <a href="https://twitter.com/FundsExplorer"><img alt="Logo do Twitter" src="/assets/icons/twitter-a2cc07e2da5f422bb62b9fb6aec721215f269eedb70ab32bcd91fbfee6ca527c.png"></a>
#           <a href="https://www.youtube.com/c/FundsExplorer"><img alt="Logo do Youtube" src="/assets/icons/youtube-53ca0b872e458e1b38e5a710ea72749fb527a9c693e929dfe0ec0d56149df8e1.png"></a>
#           <a href="https://www.instagram.com/fundsexplorer/"><img alt="Logo do Instagram" src="/assets/icons/instagram-5b71e434f89bf3be1c7049d8912a5314b090797498cee9b959eb8e125b6cc74b.png"></a>
#         </div>
#       </div>
#     </div>
#     <div class="row">
#       <div class="col-md-12 col-xs-12">
#         <div id="informative-links">
#           <a href="https://lp.fundsexplorer.com.br/carteira-de-investimento-em-fiis/"> Assine Agora</a>
#           <span>|</span>
#           <a href="/contato">Contato</a>
#           <span>|</span>
#           <a href="/termos-de-uso"> Termos de Uso</a>
#           <span>|</span>
#           <a href="/politica-de-privacidade"> Política de Privacidade</a>
#         </div>
#       </div>
#     </div>
#     <div class="row">
#       <div class="col-md-12 col-xs-12">
#         <div id="copyright-top">
#           <p>Todos os direitos são reservados. Nenhuma parte deste site pode ser reproduzida ou transmitida livremente de alguma forma, sem o consentimento prévio dos seus autores. Se por ventura tiver interessado na publicação de uma análise ao site, entre em contato via e-mail ou no formulário disponível no site.</p>
#         </div>
#       </div>
#     </div>
#     <div class="row">
#       <div class="col-md-12 col-xs-12">
#         <div id="copyright-bottom">
#           <span>Funds Explorer © 2016-2020</span>
#         </div>
#       </div>
#     </div>
#   </div>
# </footer>
#
#     <script src="/assets/redesign/application-3ebb2610266bcc0b78a59ede427970adc781353a015971a9c4a04ce2963bd7c8.js" btdata-turbolinks-track="false"></script>
#
#     <script type="text/javascript" src="https://my.hellobar.com/a1ba85854cd77f119e4dfb20f402fb4dee27081d.js"></script>
#     <script type="text/javascript">
#         function addEvent(obj, evt, fn) {
#             if (obj.addEventListener) {
#                 obj.addEventListener(evt, fn, false);
#             } else if (obj.attachEvent) {
#                 obj.attachEvent("on" + evt, fn);
#             }
#         }
#
#         //addEvent(window, "load", function(e) {
#         //    addEvent(document, "mouseout", function(e) {
#         //        e = e ? e : window.event;
#         //        var from = e.relatedTarget || e.toElement;
#         //        if (!from || from.nodeName == "HTML") {
#         //            if (!window.sessionStorage.getItem("popup-semana-cris-show")) {
#         //                $('.modal-home').fadeTo(200, 1);
#         //                window.sessionStorage.setItem("popup-semana-cris-show", "1");
#         //            }
#         //        }
#         //    });
#         //});
#
#         $(".fechar").click(function() {
#             $(".modal-home").fadeOut(200);
#         });
#     </script>
#
#
# <iframe src="//static.hotmart.com/hot-gdpr/cookieconsent.html" id="cookieconsent-frame" style="position: fixed; bottom: 0px; left: 0px; width: 100%; height: auto; border: none; min-height: 60px; z-index: 9999; display: none;"></iframe><img id="px_img" src="https://identification.hotmart.com/id.gif?cid=159357400976374668355750490800&amp;bid=159357400976374668355750490800" width="0" height="0" style="display: none;"></body></html>
