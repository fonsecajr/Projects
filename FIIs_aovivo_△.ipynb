# %% [markdown]
# <a href="https://colab.research.google.com/github/fonsecajr/Projects/blob/master/FIIs_aovivo_%E2%96%B3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Instalando as Bibliotecas

# %%
# https://github.com/burnash/gspread /if error restart the process /if error factory reset the Runtime /make sure to copy all authcode
from google.colab import auth
auth.authenticate_user()
import gspread
from oauth2client.client import GoogleCredentials
gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Mounting the G Drive /make sure to copy all authcode.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Load FIIs aovivo △
wb = gc.open_by_url('https://docs.google.com/spreadsheets/d/1T-Nkfj5ZUI7lwbjLeCYJu5ara482YFrXFxDv2tu35IA/')

# %%
# Select the right Sheet
sheet = wb.worksheet('Principal')

# %%
# Grab the data
data = sheet.get_all_values()

# %%
data
# Out:
# [['Código do Fundo B3\n',
#   'Código do Fundo',
#   'Setor',
#   'Ifix',
#   'Razão Social',
#   'VPA',
#   'P/VPA %',
#   'Price',
#   'Price Open',
#   'Price Change %',
#   'Variação Preço',
#   'Price -14 Days',
#   'Price -7 Days',
#   'The 52-week low price',
#   'The 52-week high price',
#   'Price from High %',
#   'Sparkline 52-week',
#   'Sparkline 60',
#   'Sparkline 7',
#   'tradingview',
#   'tradingview Technicals',
#   'Google',
#   'Statusinest',
#   'fundsexplorer',
#   'Liquidez Diária',
#   'Dividendo',
#   'Dividend\nYield',
#   'DY Ano',
#   'DY (12M)\nMédia',
#   'DY (6M)\nMédia',
#   'DY (3M)\nMédia',
#   'DY (12M)\nAcumulado',
#   'DY (6M)\nAcumulado',
#   'DY (3M)\nAcumulado',
#   'Patrimônio\nLíq.',
#   'DY\nPatrimonial',
#   'Variação\nPatrimonial',
#   'Rentab.\nPeríodo',
#   'Rentab.\nAcumulada',
#   'Rentab. Patr.\nno Período',
#   'Rentab. Patr.\nAcumulada',
#   'Vacância\nFísica',
#   'Vacância\nFinanceira',
#   'Quantidade\nAtivos'],
#  ['RVBI11',
# ...

# %%
# Organize the data
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.iloc[1:]

# %%
df.head()
# Out:
# 0 Código do Fundo B3\n Código do Fundo  ... Vacância\nFinanceira Quantidade\nAtivos
# 1               RVBI11          RVBI11  ...                  N/A                  0
# 2               FIVN11          FIVN11  ...                  N/A                  1
# 3               FEXC11          FEXC11  ...                  N/A                  0
# 4               XPCI11          XPCI11  ...                  N/A                  0
# 5               RECT11          RECT11  ...                  N/A                  6
#
# [5 rows x 44 columns]

# %%
df.tail()
# Out:
# 0   Código do Fundo B3\n  ... Quantidade\nAtivos
# 395               DOMC11  ...                  1
# 396              BBFI11B  ...                  2
# 397               XTED11  ...                  1
# 398               PABY11  ...                  1
# 399                       ...
#
# [5 rows x 44 columns]

# %%
df
# Out:
# 0   Código do Fundo B3\n  ... Quantidade\nAtivos
# 1                 RVBI11  ...                  0
# 2                 FIVN11  ...                  1
# 3                 FEXC11  ...                  0
# 4                 XPCI11  ...                  0
# 5                 RECT11  ...                  6
# ..                   ...  ...                ...
# 395               DOMC11  ...                  1
# 396              BBFI11B  ...                  2
# 397               XTED11  ...                  1
# 398               PABY11  ...                  1
# 399                       ...
#
# [399 rows x 44 columns]

# %%
# Organize the data .Sort data for VPA
df2 = df.sort_values(by=['P/VPA %'])

# %%
df2.head()
# Out:
# 0   Código do Fundo B3\n  ... Quantidade\nAtivos
# 200                       ...
# 136                       ...
# 137                       ...
# 138                       ...
# 139                       ...
#
# [5 rows x 44 columns]

# %%
# Organize the data .Replecing blank cell
df2.replace('', 'np.nan', inplace=True)

# %%
df2.head()
# Out:
# 0   Código do Fundo B3\n  ... Quantidade\nAtivos
# 200               np.nan  ...             np.nan
# 136               np.nan  ...             np.nan
# 137               np.nan  ...             np.nan
# 138               np.nan  ...             np.nan
# 139               np.nan  ...             np.nan
#
# [5 rows x 44 columns]

# %%
# Organize the data .Clean datafram dropping rows with np.nan looking at Ifix column.
df.dropna(subset=['Ifix'])
# Out:
# 0   Código do Fundo B3\n  ... Quantidade\nAtivos
# 1                 RVBI11  ...                  0
# 2                 FIVN11  ...                  1
# 3                 FEXC11  ...                  0
# 4                 XPCI11  ...                  0
# 5                 RECT11  ...                  6
# ..                   ...  ...                ...
# 395               DOMC11  ...                  1
# 396              BBFI11B  ...                  2
# 397               XTED11  ...                  1
# 398               PABY11  ...                  1
# 399               np.nan  ...             np.nan
#
# [399 rows x 44 columns]

# %% [markdown]
# # 2. Handling the data
