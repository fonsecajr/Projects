# %% [markdown]
# <a href="https://colab.research.google.com/github/fonsecajr/Projects/blob/master/A%C3%A7%C3%B5es_Analises11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Refer site http://www.b3.com.br/pt_br/market-data-e-indices/

# %%
import pandas as pd; pd.set_option('display.min_rows', 50); pd.set_option('display.max_rows', 200)
import numpy as np

# %%
def busca_carteira_teorica(indice):
  url = 'http://bvmf.bmfbovespa.com.br/indices/ResumoCarteiraTeorica.aspx?Indice={}&idioma=pt-br'.format(indice.upper())
  return pd.read_html(url, index_col='Código', thousands='.', decimal=',')[0][:-1]

# %%
ibov = busca_carteira_teorica('ibov')

# %%
ibov.sort_values('Part. (%)', ascending=False)
# Out:
#                 Ação       Tipo Qtde. Teórica  Part. (%)
# Código
# VALE3           VALE      ON NM    3292010807     10.515
# ITUB4   ITAUUNIBANCO      PN N1    4738562684      7.491
# B3SA3             B3      ON NM    2046021644      5.980
# PETR4      PETROBRAS      PN N2    4520185835      5.499
# BBDC4       BRADESCO      PN N1    4261649634      5.341
# PETR3      PETROBRAS      ON N2    2949857480      3.747
# ABEV3      AMBEV S/A         ON    4354228928      3.568
# BBAS3         BRASIL      ON NM    1418466803      2.738
# MGLU3    MAGAZ LUIZA      ON NM     661834080      2.725
# ITSA4         ITAUSA      PN N1    4494029326      2.649
# JBSS3            JBS      ON NM    1620646499      2.038
# LREN3   LOJAS RENNER      ON NM     785308019      1.958
# WEGE3            WEG      ON NM     689271972      1.825
# GNDI3    INTERMEDICA      ON NM     458380483      1.703
# NTCO3   GRUPO NATURA      ON NM     706484775      1.684
# ...

# %%
idiv = busca_carteira_teorica('idiv')

# %%
idiv.sort_values('Part. (%)', ascending=False)
# Out:
#                 Ação    Tipo Qtde. Teórica  Part. (%)
# Código
# EGIE3   ENGIE BRASIL   ON NM     430350077      5.381
# BBSE3   BBSEGURIDADE   ON NM     627317974      5.174
# BPAC11    BTGP BANCO  UNT N2     230517903      5.011
# ITSA4         ITAUSA   PN N1    1521145798      4.417
# CYRE3   CYRELA REALT   ON NM     652799987      4.269
# ITUB3   ITAUUNIBANCO   ON N1     585681949      4.240
# TAEE11         TAESA  UNT N2     507484570      4.188
# TRPL4   TRAN PAULIST   PN N1     706521313      4.153
# ITUB4   ITAUUNIBANCO   PN N1     497324728      3.872
# SAPR11       SANEPAR  UNT N2     400530910      3.791
# CMIG4          CEMIG   PN N1    1061002087      3.515
# MRVE3            MRV   ON NM     684267295      3.480
# SANB11  SANTANDER BR     UNT     382664019      3.371
# QUAL3      QUALICORP   ON NM     399332735      3.358
# CIEL3          CIELO   ON NM    2038696476      3.213
# PSSA3   PORTO SEGURO   ON NM     197486966      3.040
# ...

# %%
ibrx = busca_carteira_teorica('ibrx')

# %%
ibrx.sort_values('Part. (%)', ascending=False)
# Out:
#                 Ação       Tipo Qtde. Teórica  Part. (%)
# Código
# VALE3           VALE      ON NM    3292010807      9.856
# ITUB4   ITAUUNIBANCO      PN N1    4738562684      7.021
# B3SA3             B3      ON NM    2046021644      5.605
# PETR4      PETROBRAS      PN N2    4520185835      5.155
# BBDC4       BRADESCO      PN N1    4261649634      5.006
# PETR3      PETROBRAS      ON N2    2949857480      3.512
# ABEV3      AMBEV S/A         ON    4354228928      3.344
# BBAS3         BRASIL      ON NM    1418466803      2.566
# MGLU3    MAGAZ LUIZA      ON NM     661834080      2.554
# ITSA4         ITAUSA      PN N1    4494029326      2.483
# JBSS3            JBS      ON NM    1620646499      1.910
# WEGE3            WEG      ON NM     740696136      1.838
# LREN3   LOJAS RENNER      ON NM     785308019      1.835
# GNDI3    INTERMEDICA      ON NM     458380483      1.596
# NTCO3   GRUPO NATURA      ON NM     706484775      1.579
# ...

# %%
pd.concat([ibov, ibrx], keys=['IBOV', 'IBRX'], axis=1)
# Out:
#                 IBOV             ...          IBRX
#                 Ação       Tipo  ... Qtde. Teórica Part. (%)
# ABEV3      AMBEV S/A         ON  ...    4354228928     3.344
# AZUL4           AZUL      PN N2  ...     317471474     0.357
# B3SA3             B3      ON NM  ...    2046021644     5.605
# BBAS3         BRASIL      ON NM  ...    1418466803     2.566
# BBDC3       BRADESCO      ON N1  ...    1253093907     1.340
# BBDC4       BRADESCO      PN N1  ...    4261649634     5.006
# BBSE3   BBSEGURIDADE      ON NM  ...     671601167     1.054
# BEEF3        MINERVA      ON NM  ...     259260688     0.183
# BPAC11    BTGP BANCO     UNT N2  ...     201102231     0.832
# BRAP4      BRADESPAR      PN N1  ...     222089397     0.436
# BRDT3   PETROBRAS BR      ON NM  ...     728125000     0.863
# BRFS3         BRF SA      ON NM  ...     811416229     0.972
# BRKM5        BRASKEM     PNA N1  ...     264632416     0.358
# BRML3   BR MALLS PAR      ON NM  ...     843313591     0.487
# ...
